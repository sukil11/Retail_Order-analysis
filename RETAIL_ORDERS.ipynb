# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading orders.csv.zip to C:\Users\SukilPriya
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 293kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 293kB/s]

# %%
import zipfile
zip_ref=zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
df = pd.read_csv("orders.csv")
df.head(5)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    Discount Percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
df.isnull().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           1
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
df = df.fillna(value = 0)
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      Sub Category       Product Id  cost price  List Price  Quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       Discount Percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Mode           0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Category            0
# Sub Category        0
# Product Id          0
# cost price          0
# List Price          0
# Quantity            0
# Discount Percent    0
# dtype: int64

# %%
# columns rename
df = df.rename(columns={
    'Order Id': 'order_id',
    'Ship Mode': 'ship_mode',
    'Order Date': 'order_date',
    'Postal Code': 'postal_code',
    'Sub Category': 'sub_category',
    'Product Id': 'product_id',
    'cost price': 'cost_price',
    'List Price': 'list_price',
    'Discount Percent': 'discount_percent'
})
df.columns = df.columns.str.lower()
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]

# %%
# adding 3 columns
df['discount']=df['list_price']*df['discount_percent']*.01
df['sale_price']=df['list_price']-df['discount']
df['profit']=df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sale_price  profit
# 0                    2       5.2       254.8    14.8
# 1                    3      21.9       708.1   108.1
# 2                    5       0.5         9.5    -0.5
# 3                    2      19.2       940.8   160.8
# 4                    5       1.0        19.0    -1.0
# ...                ...       ...         ...     ...
# 9989                 4       1.2        28.8    -1.2
# 9990                 4       3.6        86.4    16.4
# 9991                 2       5.2       254.8    34.8
# 9992                 3       0.9        29.1    -0.9
# 9993                 3       7.2       232.8    22.8
#
# [9994 rows x 19 columns]

# %%
# table trimming
df = df.applymap(lambda x: x.rstrip() if isinstance(x, str) else x)
print("\nAfter trimming:")
df
# Out:
# After trimming:
# C:\Users\SukilPriya\AppData\Local\Temp\ipykernel_9584\3091852635.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.rstrip() if isinstance(x, str) else x)
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sale_price  profit
# 0                    2       5.2       254.8    14.8
# 1                    3      21.9       708.1   108.1
# 2                    5       0.5         9.5    -0.5
# 3                    2      19.2       940.8   160.8
# 4                    5       1.0        19.0    -1.0
# ...                ...       ...         ...     ...
# 9989                 4       1.2        28.8    -1.2
# 9990                 4       3.6        86.4    16.4
# 9991                 2       5.2       254.8    34.8
# 9992                 3       0.9        29.1    -0.9
# 9993                 3       7.2       232.8    22.8
#
# [9994 rows x 19 columns]

# %%
# Table two split
df1=df[['order_id','order_date','ship_mode','country','state','city','postal_code','region','category','sub_category']] 
df1
# Out:
#       order_id  order_date       ship_mode        country       state  \
# 0            1  2023-03-01    Second Class  United States    Kentucky
# 1            2  2023-08-15    Second Class  United States    Kentucky
# 2            3  2023-01-10    Second Class  United States  California
# 3            4  2022-06-18  Standard Class  United States     Florida
# 4            5  2022-07-13  Standard Class  United States     Florida
# ...        ...         ...             ...            ...         ...
# 9989      9990  2023-02-18    Second Class  United States     Florida
# 9990      9991  2023-03-17  Standard Class  United States  California
# 9991      9992  2022-08-07  Standard Class  United States  California
# 9992      9993  2022-11-19  Standard Class  United States  California
# 9993      9994  2022-07-17    Second Class  United States  California
#
#                  city  postal_code region         category sub_category
# 0           Henderson        42420  South        Furniture    Bookcases
# 1           Henderson        42420  South        Furniture       Chairs
# 2         Los Angeles        90036   West  Office Supplies       Labels
# 3     Fort Lauderdale        33311  South        Furniture       Tables
# 4     Fort Lauderdale        33311  South  Office Supplies      Storage
# ...               ...          ...    ...              ...          ...
# 9989            Miami        33180  South        Furniture  Furnishings
# 9990       Costa Mesa        92627   West        Furniture  Furnishings
# 9991       Costa Mesa        92627   West       Technology       Phones
# 9992       Costa Mesa        92627   West  Office Supplies        Paper
# 9993      Westminster        92683   West  Office Supplies   Appliances
#
# [9994 rows x 10 columns]

# %%
df2=df[['segment','product_id','cost_price','list_price','quantity','discount_percent','discount','sale_price','profit']]
df2
# Out:
#         segment       product_id  cost_price  list_price  quantity  \
# 0      Consumer  FUR-BO-10001798         240         260         2
# 1      Consumer  FUR-CH-10000454         600         730         3
# 2     Corporate  OFF-LA-10000240          10          10         2
# 3      Consumer  FUR-TA-10000577         780         960         5
# 4      Consumer  OFF-ST-10000760          20          20         2
# ...         ...              ...         ...         ...       ...
# 9989   Consumer  FUR-FU-10001889          30          30         3
# 9990   Consumer  FUR-FU-10000747          70          90         2
# 9991   Consumer  TEC-PH-10003645         220         260         2
# 9992   Consumer  OFF-PA-10004041          30          30         4
# 9993   Consumer  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sale_price  profit
# 0                    2       5.2       254.8    14.8
# 1                    3      21.9       708.1   108.1
# 2                    5       0.5         9.5    -0.5
# 3                    2      19.2       940.8   160.8
# 4                    5       1.0        19.0    -1.0
# ...                ...       ...         ...     ...
# 9989                 4       1.2        28.8    -1.2
# 9990                 4       3.6        86.4    16.4
# 9991                 2       5.2       254.8    34.8
# 9992                 3       0.9        29.1    -0.9
# 9993                 3       7.2       232.8    22.8
#
# [9994 rows x 9 columns]

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\sukilpriya\anaconda3\lib\site-packages (9.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
mydb = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='sukil',
    auth_plugin='mysql_native_password')
data = mydb.cursor()

# %%
data.execute("CREATE DATABASE retail_orders")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'retail_orders'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data.execute("CREATE DATABASE retail_orders")
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:351, in CMySQLCursor.execute(self, operation, params, map_results)
#     343 self._executed = (
#     344     self._stmt_partition["single_stmts"].popleft()
#     345     if map_results
#     346     else self._stmt_partition["mappable_stmt"]
#     347 )
#     349 try:
#     350     self._handle_result(
# --> 351         self._connection.cmd_query(
#     352             self._stmt_partition["mappable_stmt"],
#     353             raw=self._raw,
#     354             buffered=self._buffered,
#     355             raw_as_string=self._raw_as_string,
#     356         )
#     357     )
#     358 except MySQLInterfaceError as err:
#     359     raise get_mysql_exception(
#     360         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     361     ) from err
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:763, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#    (...)
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
# --> 763     raise get_mysql_exception(
#     764         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     765     ) from err
#     766 except AttributeError as err:
#     767     addr = (
#     768         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     769     )
#
# DatabaseError: 1007 (HY000): Can't create database 'retail_orders'; database exists

# %%
data.execute("SHOW DATABASES")
for x in data:

  print(x)
# Out:
# ('employee',)
# ('gr',)
# ('information_schema',)
# ('mgr',)
# ('mysql',)
# ('performance_schema',)
# ('r',)
# ('retail',)
# ('retail_orders',)
# ('retailorder',)
# ('rip',)
# ('rl',)
# ('ro',)
# ('rpo',)
# ('rtl',)
# ('skl',)
# ('suki',)
# ('sys',)
# ('yee',)
# ('youtube',)

# %%
# df1 insert into mysql
df1=df[['order_id','order_date','ship_mode','country','state','city','postal_code','region','category','sub_category']] 
df1
# Out:
#       order_id  order_date       ship_mode        country       state  \
# 0            1  2023-03-01    Second Class  United States    Kentucky
# 1            2  2023-08-15    Second Class  United States    Kentucky
# 2            3  2023-01-10    Second Class  United States  California
# 3            4  2022-06-18  Standard Class  United States     Florida
# 4            5  2022-07-13  Standard Class  United States     Florida
# ...        ...         ...             ...            ...         ...
# 9989      9990  2023-02-18    Second Class  United States     Florida
# 9990      9991  2023-03-17  Standard Class  United States  California
# 9991      9992  2022-08-07  Standard Class  United States  California
# 9992      9993  2022-11-19  Standard Class  United States  California
# 9993      9994  2022-07-17    Second Class  United States  California
#
#                  city  postal_code region         category sub_category
# 0           Henderson        42420  South        Furniture    Bookcases
# 1           Henderson        42420  South        Furniture       Chairs
# 2         Los Angeles        90036   West  Office Supplies       Labels
# 3     Fort Lauderdale        33311  South        Furniture       Tables
# 4     Fort Lauderdale        33311  South  Office Supplies      Storage
# ...               ...          ...    ...              ...          ...
# 9989            Miami        33180  South        Furniture  Furnishings
# 9990       Costa Mesa        92627   West        Furniture  Furnishings
# 9991       Costa Mesa        92627   West       Technology       Phones
# 9992       Costa Mesa        92627   West  Office Supplies        Paper
# 9993      Westminster        92683   West  Office Supplies   Appliances
#
# [9994 rows x 10 columns]

# %%
data.execute("use retail_orders")

# %%
data.execute("""
CREATE TABLE table_0
(
    order_id int PRIMARY KEY,         
    order_date DATE NOT NULL,                
    ship_mode VARCHAR(50),                   
    country VARCHAR(100),                   
    state VARCHAR(100),                     
    city VARCHAR(100),                     
    postal_code int,                
    region VARCHAR(50),                    
    category VARCHAR(50),                
    sub_category VARCHAR(50)              
);
""")

# %%
query = 'INSERT IGNORE INTO table_0(order_id,order_date,ship_mode,country,state,city,postal_code,region,category,sub_category) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'

# %%
file = df1.values.tolist()
file
# Out:
# [[1,
#   '2023-03-01',
#   'Second Class',
#   'United States',
#   'Kentucky',
#   'Henderson',
#   42420,
#   'South',
#   'Furniture',
#   'Bookcases'],
#  [2,
#   '2023-08-15',
#   'Second Class',
#   'United States',
#   'Kentucky',
#   'Henderson',
#   42420,
#   'South',
#   'Furniture',
#   'Chairs'],
#  [3,
#   '2023-01-10',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90036,
#   'West',
#   'Office Supplies',
#   'Labels'],
#  [4,
#   '2022-06-18',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Fort Lauderdale',
#   33311,
#   'South',
#   'Furniture',
#   'Tables'],
#  [5,
#   '2022-07-13',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Fort Lauderdale',
#   33311,
#   'South',
#   'Office Supplies',
#   'Storage'],
#  [6,
#   '2022-03-13',
#   'Not Available',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [7,
#   '2022-12-28',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [8,
#   '2022-01-25',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Technology',
#   'Phones'],
#  [9,
#   '2023-03-23',
#   'Not Available',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [10,
#   '2023-05-16',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Appliances'],
#  [11,
#   '2023-03-31',
#   'Not Available',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Furniture',
#   'Tables'],
#  [12,
#   '2023-12-25',
#   'Not Available',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Technology',
#   'Phones'],
#  [13,
#   '2022-02-11',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Concord',
#   28027,
#   'South',
#   'Office Supplies',
#   'Paper'],
#  [14,
#   '2023-07-18',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98103,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [15,
#   '2023-11-09',
#   'unknown',
#   'United States',
#   'Texas',
#   'Fort Worth',
#   76106,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [16,
#   '2022-06-18',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Fort Worth',
#   76106,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [17,
#   '2022-02-04',
#   'Standard Class',
#   'United States',
#   'Wisconsin',
#   'Madison',
#   53711,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [18,
#   '2023-08-04',
#   'Second Class',
#   'United States',
#   'Utah',
#   'West Jordan',
#   84084,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [19,
#   '2022-01-23',
#   'Second Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [20,
#   '2022-01-11',
#   'Second Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Technology',
#   'Phones'],
#  [21,
#   '2022-10-05',
#   'Second Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [22,
#   '2023-07-16',
#   'Standard Class',
#   'United States',
#   'Nebraska',
#   'Fremont',
#   68025,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [23,
#   '2023-05-06',
#   'Standard Class',
#   'United States',
#   'Nebraska',
#   'Fremont',
#   68025,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [24,
#   '2023-05-21',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Furniture',
#   'Chairs'],
#  [25,
#   '2023-02-24',
#   'Standard Class',
#   'United States',
#   'Utah',
#   'Orem',
#   84057,
#   'West',
#   'Furniture',
#   'Tables'],
#  [26,
#   '2022-06-20',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90049,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [27,
#   '2022-02-08',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90049,
#   'West',
#   'Technology',
#   'Accessories'],
#  [28,
#   '2023-12-11',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Furniture',
#   'Bookcases'],
#  [29,
#   '2022-08-21',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [30,
#   '2022-08-14',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [31,
#   '2022-11-20',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Envelopes'],
#  [32,
#   '2023-01-19',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [33,
#   '2023-01-30',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [34,
#   '2022-06-03',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [35,
#   '2022-09-28',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77095,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [36,
#   '2022-10-30',
#   'First Class',
#   'United States',
#   'Texas',
#   'Richardson',
#   75080,
#   'Central',
#   'Technology',
#   'Phones'],
#  [37,
#   '2023-07-27',
#   'First Class',
#   'United States',
#   'Texas',
#   'Richardson',
#   75080,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [38,
#   '2023-03-07',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Office Supplies',
#   'Envelopes'],
#  [39,
#   '2023-08-18',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Furniture',
#   'Bookcases'],
#  [40,
#   '2022-01-20',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [41,
#   '2023-06-29',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Technology',
#   'Phones'],
#  [42,
#   '2022-06-28',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Naperville',
#   60540,
#   'Central',
#   'Technology',
#   'Phones'],
#  [43,
#   '2023-02-09',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90049,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [44,
#   '2023-09-18',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Melbourne',
#   32935,
#   'South',
#   'Office Supplies',
#   'Storage'],
#  [45,
#   '2022-11-11',
#   'First Class',
#   'United States',
#   'Minnesota',
#   'Eagan',
#   55122,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [46,
#   '2022-05-27',
#   'First Class',
#   'United States',
#   'Minnesota',
#   'Eagan',
#   55122,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [47,
#   '2023-02-03',
#   'Second Class',
#   'United States',
#   'Michigan',
#   'Westland',
#   48185,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [48,
#   '2022-02-16',
#   'Standard Class',
#   'United States',
#   'Delaware',
#   'Dover',
#   19901,
#   'East',
#   'Technology',
#   'Accessories'],
#  [49,
#   '2022-05-06',
#   'Standard Class',
#   'United States',
#   'Delaware',
#   'Dover',
#   19901,
#   'East',
#   'Technology',
#   'Phones'],
#  [50,
#   '2023-06-18',
#   'Standard Class',
#   'United States',
#   'Indiana',
#   'New Albany',
#   47150,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [51,
#   '2022-01-11',
#   'Standard Class',
#   'United States',
#   'Indiana',
#   'New Albany',
#   47150,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [52,
#   '2023-09-09',
#   'Standard Class',
#   'United States',
#   'Indiana',
#   'New Albany',
#   47150,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [53,
#   '2022-01-31',
#   'Standard Class',
#   'United States',
#   'Indiana',
#   'New Albany',
#   47150,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [54,
#   '2023-07-30',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Office Supplies',
#   'Fasteners'],
#  [55,
#   '2023-10-17',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Technology',
#   'Phones'],
#  [56,
#   '2023-07-06',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [57,
#   '2023-09-15',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [58,
#   '2022-08-09',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Furniture',
#   'Chairs'],
#  [59,
#   '2022-04-05',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [60,
#   '2023-06-24',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Technology',
#   'Accessories'],
#  [61,
#   '2022-03-10',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [62,
#   '2023-04-08',
#   'First Class',
#   'United States',
#   'New York',
#   'Troy',
#   12180,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [63,
#   '2023-10-16',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Technology',
#   'Accessories'],
#  [64,
#   '2023-08-02',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [65,
#   '2022-11-05',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [66,
#   '2022-05-06',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [67,
#   '2022-03-26',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [68,
#   '2022-04-10',
#   'Standard Class',
#   'United States',
#   'Arizona',
#   'Gilbert',
#   85234,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [69,
#   '2022-08-12',
#   'Standard Class',
#   'United States',
#   'Arizona',
#   'Gilbert',
#   85234,
#   'West',
#   'Technology',
#   'Phones'],
#  [70,
#   '2022-02-25',
#   'First Class',
#   'United States',
#   'Virginia',
#   'Springfield',
#   22153,
#   'South',
#   'Office Supplies',
#   'Paper'],
#  [71,
#   '2022-11-29',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [72,
#   '2022-12-18',
#   'Second Class',
#   'United States',
#   'Michigan',
#   'Jackson',
#   49201,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [73,
#   '2023-03-07',
#   'Standard Class',
#   'United States',
#   'Tennessee',
#   'Memphis',
#   38109,
#   'South',
#   'Furniture',
#   'Chairs'],
#  [74,
#   '2023-07-12',
#   'Standard Class',
#   'United States',
#   'Tennessee',
#   'Memphis',
#   38109,
#   'South',
#   'Furniture',
#   'Furnishings'],
#  [75,
#   '2022-10-21',
#   'Standard Class',
#   'United States',
#   'Tennessee',
#   'Memphis',
#   38109,
#   'South',
#   'Office Supplies',
#   'Storage'],
#  [76,
#   '2023-04-17',
#   'First Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [77,
#   '2023-05-20',
#   'First Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [78,
#   '2023-05-13',
#   'First Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [79,
#   '2022-10-20',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77070,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [80,
#   '2023-10-22',
#   'First Class',
#   'United States',
#   'Alabama',
#   'Decatur',
#   35601,
#   'South',
#   'Office Supplies',
#   'Appliances'],
#  [81,
#   '2022-07-20',
#   'First Class',
#   'United States',
#   'Alabama',
#   'Decatur',
#   35601,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [82,
#   '2022-11-16',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [83,
#   '2022-11-10',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [84,
#   '2022-03-15',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Durham',
#   27707,
#   'South',
#   'Office Supplies',
#   'Envelopes'],
#  [85,
#   '2023-10-03',
#   'First Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [86,
#   '2022-03-20',
#   'Second Class',
#   'United States',
#   'South Carolina',
#   'Columbia',
#   29203,
#   'South',
#   'Furniture',
#   'Chairs'],
#  [87,
#   '2023-12-04',
#   'Standard Class',
#   'United States',
#   'Minnesota',
#   'Rochester',
#   55901,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [88,
#   '2023-11-24',
#   'Standard Class',
#   'United States',
#   'Minnesota',
#   'Rochester',
#   55901,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [89,
#   '2023-12-30',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77095,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [90,
#   '2022-05-23',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90036,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [91,
#   '2023-04-06',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90036,
#   'West',
#   'Technology',
#   'Phones'],
#  [92,
#   '2022-03-23',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90036,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [93,
#   '2023-04-07',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Minneapolis',
#   55407,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [94,
#   '2022-05-13',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Minneapolis',
#   55407,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [95,
#   '2022-04-23',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Minneapolis',
#   55407,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [96,
#   '2023-12-17',
#   'Standard Class',
#   'United States',
#   'Oregon',
#   'Portland',
#   97206,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [97,
#   '2022-04-28',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [98,
#   '2023-06-14',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [99,
#   '2023-02-05',
#   'Standard Class',
#   'United States',
#   'Minnesota',
#   'Saint Paul',
#   55106,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [100,
#   '2023-12-30',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [101,
#   '2022-02-24',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [102,
#   '2022-07-25',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [103,
#   '2022-01-14',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Rochester',
#   55901,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [104,
#   '2022-12-22',
#   'Standard Class',
#   'United States',
#   'Colorado',
#   'Aurora',
#   80013,
#   'West',
#   'Technology',
#   'Accessories'],
#  [105,
#   '2022-06-09',
#   'Standard Class',
#   'United States',
#   'Colorado',
#   'Aurora',
#   80013,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [106,
#   '2023-10-28',
#   'Standard Class',
#   'United States',
#   'Colorado',
#   'Aurora',
#   80013,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [107,
#   '2022-10-18',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Charlotte',
#   28205,
#   'South',
#   'Technology',
#   'Accessories'],
#  [108,
#   '2022-11-23',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Charlotte',
#   28205,
#   'South',
#   'Technology',
#   'Phones'],
#  [109,
#   '2023-10-12',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Charlotte',
#   28205,
#   'South',
#   'Office Supplies',
#   'Art'],
#  [110,
#   '2023-03-17',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Orland Park',
#   60462,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [111,
#   '2023-09-05',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [112,
#   '2022-01-28',
#   'Standard Class',
#   'United States',
#   'Iowa',
#   'Urbandale',
#   50322,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [113,
#   '2022-12-26',
#   'Standard Class',
#   'United States',
#   'Iowa',
#   'Urbandale',
#   50322,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [114,
#   '2023-06-06',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Fasteners'],
#  [115,
#   '2023-11-08',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Envelopes'],
#  [116,
#   '2022-11-15',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [117,
#   '2022-06-30',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Envelopes'],
#  [118,
#   '2023-10-27',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98103,
#   'West',
#   'Furniture',
#   'Tables'],
#  [119,
#   '2023-07-19',
#   0,
#   'United States',
#   'Tennessee',
#   'Bristol',
#   37620,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [120,
#   '2023-03-30',
#   'First Class',
#   'United States',
#   'Delaware',
#   'Wilmington',
#   19805,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [121,
#   '2022-03-03',
#   'First Class',
#   'United States',
#   'Delaware',
#   'Wilmington',
#   19805,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [122,
#   '2022-10-20',
#   'First Class',
#   'United States',
#   'Delaware',
#   'Wilmington',
#   19805,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [123,
#   '2023-01-23',
#   'First Class',
#   'United States',
#   'Delaware',
#   'Wilmington',
#   19805,
#   'East',
#   'Office Supplies',
#   'Envelopes'],
#  [124,
#   '2023-01-21',
#   'First Class',
#   'United States',
#   'Delaware',
#   'Wilmington',
#   19805,
#   'East',
#   'Technology',
#   'Phones'],
#  [125,
#   '2023-07-18',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [126,
#   '2023-07-15',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Bloomington',
#   61701,
#   'Central',
#   'Furniture',
#   'Tables'],
#  [127,
#   '2022-07-14',
#   'Standard Class',
#   'United States',
#   'Arizona',
#   'Phoenix',
#   85023,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [128,
#   '2023-03-30',
#   'Standard Class',
#   'United States',
#   'Arizona',
#   'Phoenix',
#   85023,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [129,
#   '2023-09-18',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [130,
#   '2022-01-03',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [131,
#   '2022-07-17',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Technology',
#   'Phones'],
#  [132,
#   '2022-03-30',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [133,
#   '2022-05-01',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Fasteners'],
#  [134,
#   '2023-04-29',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [135,
#   '2022-10-28',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [136,
#   '2022-03-05',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [137,
#   '2022-03-28',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Office Supplies',
#   'Fasteners'],
#  [138,
#   '2023-10-16',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [139,
#   '2022-05-15',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Office Supplies',
#   'Supplies'],
#  [140,
#   '2023-06-06',
#   'Standard Class',
#   'United States',
#   'California',
#   'Roseville',
#   95661,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [141,
#   '2022-06-10',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [142,
#   '2022-07-22',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [143,
#   '2023-12-27',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Envelopes'],
#  [144,
#   '2023-11-29',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [145,
#   '2022-03-19',
#   'Standard Class',
#   'United States',
#   'Missouri',
#   'Independence',
#   64055,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [146,
#   '2023-06-04',
#   'Standard Class',
#   'United States',
#   'California',
#   'Pasadena',
#   91104,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [147,
#   '2023-05-31',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Newark',
#   43055,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [148,
#   '2022-06-12',
#   'Standard Class',
#   'United States',
#   'Wisconsin',
#   'Franklin',
#   53132,
#   'Central',
#   'Technology',
#   'Phones'],
#  [149,
#   '2022-05-18',
#   'Standard Class',
#   'United States',
#   'Wisconsin',
#   'Franklin',
#   53132,
#   'Central',
#   'Technology',
#   'Phones'],
#  [150,
#   '2022-01-23',
#   'Standard Class',
#   'United States',
#   'Wisconsin',
#   'Franklin',
#   53132,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [151,
#   '2023-08-21',
#   'Standard Class',
#   'United States',
#   'Wisconsin',
#   'Franklin',
#   53132,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [152,
#   '2023-08-31',
#   'First Class',
#   'United States',
#   'Arizona',
#   'Scottsdale',
#   85254,
#   'West',
#   'Office Supplies',
#   'Appliances'],
#  [153,
#   '2022-10-25',
#   'First Class',
#   'United States',
#   'Arizona',
#   'Scottsdale',
#   85254,
#   'West',
#   'Technology',
#   'Phones'],
#  [154,
#   '2022-10-07',
#   'First Class',
#   'United States',
#   'California',
#   'San Jose',
#   95123,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [155,
#   '2023-03-25',
#   'First Class',
#   'United States',
#   'California',
#   'San Jose',
#   95123,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [156,
#   '2023-03-27',
#   'First Class',
#   'United States',
#   'California',
#   'San Jose',
#   95123,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [157,
#   '2022-05-03',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98105,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [158,
#   '2022-05-18',
#   'Second Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98115,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [159,
#   '2022-04-25',
#   'Standard Class',
#   'United States',
#   'Oklahoma',
#   'Edmond',
#   73034,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [160,
#   '2022-06-30',
#   'Standard Class',
#   'United States',
#   'Oklahoma',
#   'Edmond',
#   73034,
#   'Central',
#   'Technology',
#   'Phones'],
#  [161,
#   '2022-01-10',
#   'First Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90045,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [162,
#   '2023-11-27',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Technology',
#   'Accessories'],
#  [163,
#   '2022-02-16',
#   'Standard Class',
#   'United States',
#   'New Mexico',
#   'Carlsbad',
#   88220,
#   'West',
#   'Office Supplies',
#   'Envelopes'],
#  [164,
#   '2022-08-14',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98115,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [165,
#   '2023-10-14',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [166,
#   '2022-10-16',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Technology',
#   'Machines'],
#  [167,
#   '2022-11-20',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [168,
#   '2023-11-04',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [169,
#   '2023-06-16',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [170,
#   '2022-10-20',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [171,
#   '2022-07-12',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Technology',
#   'Phones'],
#  [172,
#   '2022-01-28',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [173,
#   '2023-10-10',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [174,
#   '2022-10-05',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [175,
#   '2023-01-02',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [176,
#   '2023-04-07',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [177,
#   '2022-04-21',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77036,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [178,
#   '2023-10-28',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Newark',
#   43055,
#   'East',
#   'Furniture',
#   'Chairs'],
#  [179,
#   '2022-04-18',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Newark',
#   43055,
#   'East',
#   'Office Supplies',
#   'Supplies'],
#  [180,
#   '2022-03-08',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [181,
#   '2023-06-08',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Decatur',
#   62521,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [182,
#   '2022-06-25',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Decatur',
#   62521,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [183,
#   '2022-01-10',
#   'Second Class',
#   'United States',
#   'Louisiana',
#   'Monroe',
#   71203,
#   'South',
#   'Technology',
#   'Phones'],
#  [184,
#   '2023-10-17',
#   'Second Class',
#   'United States',
#   'Louisiana',
#   'Monroe',
#   71203,
#   'South',
#   'Technology',
#   'Phones'],
#  [185,
#   '2023-02-23',
#   'Second Class',
#   'United States',
#   'Louisiana',
#   'Monroe',
#   71203,
#   'South',
#   'Technology',
#   'Accessories'],
#  [186,
#   '2022-10-19',
#   'Standard Class',
#   'United States',
#   'Connecticut',
#   'Fairfield',
#   6824,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [187,
#   '2022-08-22',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Technology',
#   'Accessories'],
#  [188,
#   '2023-10-11',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Grand Prairie',
#   75051,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [189,
#   '2022-12-06',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Grand Prairie',
#   75051,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [190,
#   '2023-12-09',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Furniture',
#   'Bookcases'],
#  [191,
#   '2022-07-12',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Technology',
#   'Phones'],
#  [192,
#   '2022-06-23',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [193,
#   '2023-11-04',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Furniture',
#   'Bookcases'],
#  [194,
#   '2022-11-11',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [195,
#   '2023-01-07',
#   'Standard Class',
#   'United States',
#   'California',
#   'Redlands',
#   92374,
#   'West',
#   'Office Supplies',
#   'Envelopes'],
#  [196,
#   '2022-10-26',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Hamilton',
#   45011,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [197,
#   '2023-11-03',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Hamilton',
#   45011,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [198,
#   '2023-03-05',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Westfield',
#   7090,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [199,
#   '2022-12-21',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [200,
#   '2022-06-16',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [201,
#   '2022-12-11',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Akron',
#   44312,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [202,
#   '2022-07-13',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Denver',
#   80219,
#   'West',
#   'Furniture',
#   'Tables'],
#  [203,
#   '2022-12-31',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Denver',
#   80219,
#   'West',
#   'Office Supplies',
#   'Appliances'],
#  [204,
#   '2022-03-12',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Dallas',
#   75220,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [205,
#   '2023-10-14',
#   'Standard Class',
#   'United States',
#   'Tennessee',
#   'Franklin',
#   37064,
#   'South',
#   'Furniture',
#   'Furnishings'],
#  [206,
#   '2023-07-10',
#   'Standard Class',
#   'United States',
#   'California',
#   'Whittier',
#   90604,
#   'West',
#   'Technology',
#   'Phones'],
#  [207,
#   '2023-12-01',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Saginaw',
#   48601,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [208,
#   '2023-08-08',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Saginaw',
#   48601,
#   'Central',
#   'Technology',
#   'Phones'],
#  [209,
#   '2022-08-19',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Saginaw',
#   48601,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [210,
#   '2023-12-30',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Saginaw',
#   48601,
#   'Central',
#   'Office Supplies',
#   'Fasteners'],
#  [211,
#   '2022-07-17',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Saginaw',
#   48601,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [212,
#   '2023-10-07',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Dallas',
#   75220,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [213,
#   '2023-04-22',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Medina',
#   44256,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [214,
#   '2023-04-22',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Medina',
#   44256,
#   'East',
#   'Furniture',
#   'Bookcases'],
#  [215,
#   '2023-11-20',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Medina',
#   44256,
#   'East',
#   'Technology',
#   'Phones'],
#  [216,
#   '2023-03-31',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Medina',
#   44256,
#   'East',
#   'Technology',
#   'Machines'],
#  [217,
#   '2022-08-29',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Medina',
#   44256,
#   'East',
#   'Technology',
#   'Accessories'],
#  [218,
#   '2022-05-06',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [219,
#   '2023-08-10',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Technology',
#   'Phones'],
#  [220,
#   '2023-04-24',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Dublin',
#   43017,
#   'East',
#   'Office Supplies',
#   'Fasteners'],
#  [221,
#   '2022-03-24',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Dublin',
#   43017,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [222,
#   '2023-03-26',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Dublin',
#   43017,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [223,
#   '2022-04-18',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Dublin',
#   43017,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [224,
#   '2023-03-17',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Dublin',
#   43017,
#   'East',
#   'Technology',
#   'Machines'],
#  [225,
#   '2023-11-19',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Dublin',
#   43017,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [226,
#   '2023-11-18',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [227,
#   '2023-04-22',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Furniture',
#   'Tables'],
#  [228,
#   '2022-04-22',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [229,
#   '2022-02-17',
#   'Standard Class',
#   'United States',
#   'Tennessee',
#   'Columbia',
#   38401,
#   'South',
#   'Furniture',
#   'Chairs'],
#  [230,
#   '2023-10-02',
#   'Standard Class',
#   'United States',
#   'Tennessee',
#   'Columbia',
#   38401,
#   'South',
#   'Furniture',
#   'Chairs'],
#  [231,
#   '2023-07-21',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Charlotte',
#   28205,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [232,
#   '2023-01-18',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Tampa',
#   33614,
#   'South',
#   'Furniture',
#   'Tables'],
#  [233,
#   '2023-10-19',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Tampa',
#   33614,
#   'South',
#   'Furniture',
#   'Tables'],
#  [234,
#   '2023-09-13',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Tampa',
#   33614,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [235,
#   '2023-11-10',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Tampa',
#   33614,
#   'South',
#   'Furniture',
#   'Furnishings'],
#  [236,
#   '2023-11-26',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Tampa',
#   33614,
#   'South',
#   'Technology',
#   'Accessories'],
#  [237,
#   '2022-01-02',
#   'Standard Class',
#   'United States',
#   'California',
#   'Santa Clara',
#   95051,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [238,
#   '2022-01-19',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [239,
#   '2023-12-13',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [240,
#   '2023-01-20',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [241,
#   '2023-04-25',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Technology',
#   'Phones'],
#  [242,
#   '2023-05-27',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Furniture',
#   'Tables'],
#  [243,
#   '2022-11-08',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [244,
#   '2022-01-08',
#   'Second Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [245,
#   '2022-04-20',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Lakeville',
#   55044,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [246,
#   '2022-11-09',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Lakeville',
#   55044,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [247,
#   '2023-04-29',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Lakeville',
#   55044,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [248,
#   '2023-04-28',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Lakeville',
#   55044,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [249,
#   '2022-09-26',
#   'Second Class',
#   'United States',
#   'Minnesota',
#   'Lakeville',
#   55044,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [250,
#   '2023-08-18',
#   'Second Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [251,
#   '2023-09-19',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Diego',
#   92037,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [252,
#   '2022-05-28',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Diego',
#   92037,
#   'West',
#   'Technology',
#   'Accessories'],
#  [253,
#   '2022-04-03',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [254,
#   '2022-04-18',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Office Supplies',
#   'Envelopes'],
#  [255,
#   '2022-12-25',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [256,
#   '2022-11-26',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [257,
#   '2022-04-25',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [258,
#   '2023-04-08',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Technology',
#   'Phones'],
#  [259,
#   '2022-02-10',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Technology',
#   'Accessories'],
#  [260,
#   '2022-10-20',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [261,
#   '2022-06-11',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [262,
#   '2023-08-29',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Pasadena',
#   77506,
#   'Central',
#   'Office Supplies',
#   'Appliances'],
#  [263,
#   '2022-12-26',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77036,
#   'Central',
#   'Technology',
#   'Machines'],
#  [264,
#   '2022-06-14',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77036,
#   'Central',
#   'Technology',
#   'Machines'],
#  [265,
#   '2023-06-20',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60610,
#   'Central',
#   'Technology',
#   'Phones'],
#  [266,
#   '2022-11-17',
#   'Standard Class',
#   'United States',
#   'California',
#   'Brentwood',
#   94513,
#   'West',
#   'Technology',
#   'Accessories'],
#  [267,
#   '2023-10-25',
#   'Standard Class',
#   'United States',
#   'North Carolina',
#   'Chapel Hill',
#   27514,
#   'South',
#   'Office Supplies',
#   'Art'],
#  [268,
#   '2022-05-19',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Morristown',
#   7960,
#   'East',
#   'Office Supplies',
#   'Fasteners'],
#  [269,
#   '2022-08-10',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Cincinnati',
#   45231,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [270,
#   '2023-12-17',
#   'Standard Class',
#   'United States',
#   'Ohio',
#   'Cincinnati',
#   45231,
#   'East',
#   'Office Supplies',
#   'Envelopes'],
#  [271,
#   '2022-01-24',
#   'Second Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94110,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [272,
#   '2022-09-16',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Technology',
#   'Accessories'],
#  [273,
#   '2022-11-29',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [274,
#   '2022-10-31',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94109,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [275,
#   '2023-02-05',
#   'First Class',
#   'United States',
#   'California',
#   'Inglewood',
#   90301,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [276,
#   '2023-04-04',
#   'First Class',
#   'United States',
#   'California',
#   'Inglewood',
#   90301,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [277,
#   '2023-10-20',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [278,
#   '2022-05-21',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [279,
#   '2022-03-10',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [280,
#   '2022-05-17',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [281,
#   '2022-10-06',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77070,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [282,
#   '2023-05-06',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77070,
#   'Central',
#   'Technology',
#   'Phones'],
#  [283,
#   '2023-10-05',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90004,
#   'West',
#   'Furniture',
#   'Tables'],
#  [284,
#   '2022-07-28',
#   'Standard Class',
#   'United States',
#   'Oregon',
#   'Portland',
#   97206,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [285,
#   '2022-12-11',
#   'Standard Class',
#   'United States',
#   'Oregon',
#   'Portland',
#   97206,
#   'West',
#   'Technology',
#   'Accessories'],
#  [286,
#   '2022-08-01',
#   'Standard Class',
#   'United States',
#   'Oregon',
#   'Portland',
#   97206,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [287,
#   '2022-01-20',
#   'Second Class',
#   'United States',
#   'Florida',
#   'Tamarac',
#   33319,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [288,
#   '2023-06-05',
#   'Second Class',
#   'United States',
#   'Florida',
#   'Tamarac',
#   33319,
#   'South',
#   'Office Supplies',
#   'Appliances'],
#  [289,
#   '2023-04-01',
#   'Second Class',
#   'United States',
#   'Florida',
#   'Tamarac',
#   33319,
#   'South',
#   'Office Supplies',
#   'Supplies'],
#  [290,
#   '2022-01-23',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Fasteners'],
#  [291,
#   '2023-10-12',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [292,
#   '2023-06-22',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Technology',
#   'Accessories'],
#  [293,
#   '2023-07-12',
#   'Second Class',
#   'United States',
#   'Ohio',
#   'Columbus',
#   43229,
#   'East',
#   'Furniture',
#   'Bookcases'],
#  [294,
#   '2023-06-20',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Colorado Springs',
#   80906,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [295,
#   '2023-05-30',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Colorado Springs',
#   80906,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [296,
#   '2023-08-05',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Colorado Springs',
#   80906,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [297,
#   '2023-11-17',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Colorado Springs',
#   80906,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [298,
#   '2023-08-04',
#   'First Class',
#   'United States',
#   'Colorado',
#   'Colorado Springs',
#   80906,
#   'West',
#   'Office Supplies',
#   'Fasteners'],
#  [299,
#   '2022-09-25',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Belleville',
#   7109,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [300,
#   '2022-09-24',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Belleville',
#   7109,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [301,
#   '2022-03-12',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Belleville',
#   7109,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [302,
#   '2022-10-31',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Belleville',
#   7109,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [303,
#   '2022-06-29',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Belleville',
#   7109,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [304,
#   '2023-09-12',
#   'Standard Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60623,
#   'Central',
#   'Furniture',
#   'Tables'],
#  [305,
#   '2022-01-08',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [306,
#   '2023-09-01',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Taylor',
#   48180,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [307,
#   '2023-10-12',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Lakewood',
#   8701,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [308,
#   '2023-08-15',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Lakewood',
#   8701,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [309,
#   '2022-05-05',
#   'First Class',
#   'United States',
#   'Virginia',
#   'Arlington',
#   22204,
#   'South',
#   'Office Supplies',
#   'Art'],
#  [310,
#   '2023-08-06',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Arvada',
#   80004,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [311,
#   '2022-09-08',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Arvada',
#   80004,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [312,
#   '2022-05-30',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Arvada',
#   80004,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [313,
#   '2023-01-13',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Arvada',
#   80004,
#   'West',
#   'Office Supplies',
#   'Labels'],
#  [314,
#   '2023-09-15',
#   'Standard Class',
#   'United States',
#   'New Jersey',
#   'Hackensack',
#   7601,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [315,
#   '2022-05-12',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Saint Petersburg',
#   33710,
#   'South',
#   'Technology',
#   'Phones'],
#  [316,
#   '2022-03-10',
#   'Standard Class',
#   'United States',
#   'Florida',
#   'Saint Petersburg',
#   33710,
#   'South',
#   'Office Supplies',
#   'Paper'],
#  [317,
#   '2023-06-16',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [318,
#   '2022-03-13',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Furniture',
#   'Chairs'],
#  [319,
#   '2022-01-28',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Technology',
#   'Machines'],
#  [320,
#   '2023-12-09',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Technology',
#   'Phones'],
#  [321,
#   '2023-07-12',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Technology',
#   'Accessories'],
#  [322,
#   '2022-05-28',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [323,
#   '2023-01-02',
#   'Standard Class',
#   'United States',
#   'California',
#   'Long Beach',
#   90805,
#   'West',
#   'Office Supplies',
#   'Fasteners'],
#  [324,
#   '2022-07-14',
#   'Standard Class',
#   'United States',
#   'California',
#   'Hesperia',
#   92345,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [325,
#   '2023-12-09',
#   'Standard Class',
#   'United States',
#   'California',
#   'Hesperia',
#   92345,
#   'West',
#   'Technology',
#   'Accessories'],
#  [326,
#   '2022-12-07',
#   'Second Class',
#   'United States',
#   'Tennessee',
#   'Murfreesboro',
#   37130,
#   'South',
#   'Furniture',
#   'Furnishings'],
#  [327,
#   '2023-06-11',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Technology',
#   'Phones'],
#  [328,
#   '2023-10-01',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [329,
#   '2023-04-07',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Furniture',
#   'Chairs'],
#  [330,
#   '2023-10-03',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [331,
#   '2022-03-30',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [332,
#   '2022-04-11',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Technology',
#   'Phones'],
#  [333,
#   '2022-03-21',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [334,
#   '2022-05-04',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [335,
#   '2023-07-08',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90045,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [336,
#   '2022-08-30',
#   'Second Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90045,
#   'West',
#   'Technology',
#   'Copiers'],
#  [337,
# ...
#  [890,
#   '2022-01-11',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New Rochelle',
#   10801,
#   'East',
#   'Technology',
#   'Accessories'],
#  [891,
#   '2022-02-10',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New Rochelle',
#   10801,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [892,
#   '2022-05-03',
#   'First Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [893,
#   '2023-04-07',
#   'First Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [894,
#   '2023-02-07',
#   'First Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Technology',
#   'Phones'],
#  [895,
#   '2022-12-05',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [896,
#   '2022-05-13',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94122,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [897,
#   '2023-11-20',
#   'Second Class',
#   'United States',
#   'Texas',
#   'Houston',
#   77095,
#   'Central',
#   'Office Supplies',
#   'Envelopes'],
#  [898,
#   '2022-10-17',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48227,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [899,
#   '2023-02-06',
#   'Second Class',
#   'United States',
#   'New York',
#   'Auburn',
#   13021,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [900,
#   '2022-10-20',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Springfield',
#   45503,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [901,
#   '2023-05-20',
#   'First Class',
#   'United States',
#   'Texas',
#   'Garland',
#   75043,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [902,
#   '2023-09-09',
#   'First Class',
#   'United States',
#   'Texas',
#   'Garland',
#   75043,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [903,
#   '2022-06-28',
#   'First Class',
#   'United States',
#   'Illinois',
#   'Chicago',
#   60653,
#   'Central',
#   'Technology',
#   'Phones'],
#  [904,
#   '2023-12-01',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [905,
#   '2022-05-25',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [906,
#   '2022-04-23',
#   'Standard Class',
#   'United States',
#   'California',
#   'Los Angeles',
#   90032,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [907,
#   '2023-11-26',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Furniture',
#   'Bookcases'],
#  [908,
#   '2022-07-25',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Technology',
#   'Phones'],
#  [909,
#   '2023-07-06',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [910,
#   '2023-03-30',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Jackson',
#   49201,
#   'Central',
#   'Technology',
#   'Phones'],
#  [911,
#   '2023-12-31',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Jackson',
#   49201,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [912,
#   '2022-06-08',
#   'Standard Class',
#   'United States',
#   'Michigan',
#   'Jackson',
#   49201,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [913,
#   '2023-06-21',
#   'Standard Class',
#   'United States',
#   'Connecticut',
#   'Norwich',
#   6360,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [914,
#   '2023-05-09',
#   'First Class',
#   'United States',
#   'Wisconsin',
#   'Milwaukee',
#   53209,
#   'Central',
#   'Furniture',
#   'Furnishings'],
#  [915,
#   '2023-05-29',
#   'First Class',
#   'United States',
#   'Wisconsin',
#   'Milwaukee',
#   53209,
#   'Central',
#   'Technology',
#   'Accessories'],
#  [916,
#   '2023-03-03',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Furniture',
#   'Tables'],
#  [917,
#   '2023-05-17',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Furniture',
#   'Chairs'],
#  [918,
#   '2022-12-18',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'San Antonio',
#   78207,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [919,
#   '2022-06-28',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Dallas',
#   75220,
#   'Central',
#   'Office Supplies',
#   'Envelopes'],
#  [920,
#   '2022-03-13',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Dallas',
#   75220,
#   'Central',
#   'Office Supplies',
#   'Storage'],
#  [921,
#   '2022-12-18',
#   'Standard Class',
#   'United States',
#   'Virginia',
#   'Alexandria',
#   22304,
#   'South',
#   'Office Supplies',
#   'Storage'],
#  [922,
#   '2022-12-07',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Technology',
#   'Accessories'],
#  [923,
#   '2022-03-17',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Technology',
#   'Phones'],
#  [924,
#   '2023-03-13',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10009,
#   'East',
#   'Office Supplies',
#   'Appliances'],
#  [925,
#   '2022-08-04',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [926,
#   '2022-05-23',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [927,
#   '2023-01-23',
#   'First Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Technology',
#   'Accessories'],
#  [928,
#   '2022-05-23',
#   'Standard Class',
#   'United States',
#   'Virginia',
#   'Springfield',
#   22153,
#   'South',
#   'Office Supplies',
#   'Art'],
#  [929,
#   '2022-02-22',
#   'Standard Class',
#   'United States',
#   'Virginia',
#   'Springfield',
#   22153,
#   'South',
#   'Office Supplies',
#   'Appliances'],
#  [930,
#   '2022-02-23',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Toledo',
#   43615,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [931,
#   '2022-08-08',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Toledo',
#   43615,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [932,
#   '2022-06-27',
#   'First Class',
#   'United States',
#   'Ohio',
#   'Toledo',
#   43615,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [933,
#   '2022-09-04',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19140,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [934,
#   '2023-09-09',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [935,
#   '2022-07-18',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [936,
#   '2022-05-12',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [937,
#   '2023-12-13',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Appliances'],
#  [938,
#   '2022-10-11',
#   'First Class',
#   'United States',
#   'New Mexico',
#   'Farmington',
#   87401,
#   'West',
#   'Technology',
#   'Accessories'],
#  [939,
#   '2023-05-31',
#   'Standard Class',
#   'United States',
#   'California',
#   'Riverside',
#   92503,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [940,
#   '2022-12-18',
#   'Standard Class',
#   'United States',
#   'California',
#   'Riverside',
#   92503,
#   'West',
#   'Office Supplies',
#   'Appliances'],
#  [941,
#   '2023-07-11',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94110,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [942,
#   '2023-02-15',
#   'Standard Class',
#   'United States',
#   'California',
#   'Torrance',
#   90503,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [943,
#   '2023-04-06',
#   'Standard Class',
#   'United States',
#   'California',
#   'Torrance',
#   90503,
#   'West',
#   'Furniture',
#   'Tables'],
#  [944,
#   '2023-12-25',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98105,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [945,
#   '2023-07-14',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98105,
#   'West',
#   'Office Supplies',
#   'Storage'],
#  [946,
#   '2022-03-03',
#   'Standard Class',
#   'United States',
#   'Washington',
#   'Seattle',
#   98105,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [947,
#   '2023-04-20',
#   'First Class',
#   'United States',
#   'Arizona',
#   'Mesa',
#   85204,
#   'West',
#   'Furniture',
#   'Tables'],
#  [948,
#   '2022-06-09',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [949,
#   '2022-06-15',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [950,
#   '2022-07-09',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Furniture',
#   'Tables'],
#  [951,
#   '2022-03-19',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [952,
#   '2022-05-14',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19120,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [953,
#   '2023-04-23',
#   'Standard Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19143,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [954,
#   '2022-08-03',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Round Rock',
#   78664,
#   'Central',
#   'Office Supplies',
#   'Art'],
#  [955,
#   '2023-11-15',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Round Rock',
#   78664,
#   'Central',
#   'Furniture',
#   'Bookcases'],
#  [956,
#   '2022-02-07',
#   'Standard Class',
#   'United States',
#   'Mississippi',
#   'Jackson',
#   39212,
#   'South',
#   'Office Supplies',
#   'Storage'],
#  [957,
#   '2022-08-20',
#   'Second Class',
#   'United States',
#   'Arizona',
#   'Phoenix',
#   85023,
#   'West',
#   'Technology',
#   'Phones'],
#  [958,
#   '2022-06-29',
#   'Second Class',
#   'United States',
#   'Arizona',
#   'Phoenix',
#   85023,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [959,
#   '2022-10-23',
#   'Second Class',
#   'United States',
#   'Arizona',
#   'Phoenix',
#   85023,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [960,
#   '2022-05-15',
#   'Same Day',
#   'United States',
#   'California',
#   'Oceanside',
#   92054,
#   'West',
#   'Furniture',
#   'Furnishings'],
#  [961,
#   '2023-09-04',
#   'Standard Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94110,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [962,
#   '2023-10-23',
#   'Standard Class',
#   'United States',
#   'Arkansas',
#   'Fayetteville',
#   72701,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [963,
#   '2023-08-16',
#   'First Class',
#   'United States',
#   'California',
#   'San Francisco',
#   94110,
#   'West',
#   'Office Supplies',
#   'Envelopes'],
#  [964,
#   '2022-09-13',
#   'Second Class',
#   'United States',
#   'Florida',
#   'Boca Raton',
#   33433,
#   'South',
#   'Office Supplies',
#   'Labels'],
#  [965,
#   '2022-04-30',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [966,
#   '2022-05-06',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [967,
#   '2023-07-11',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [968,
#   '2023-07-05',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Paper'],
#  [969,
#   '2023-03-19',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [970,
#   '2022-10-25',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Storage'],
#  [971,
#   '2023-12-15',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [972,
#   '2022-05-29',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Technology',
#   'Phones'],
#  [973,
#   '2022-06-15',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [974,
#   '2023-05-17',
#   'Second Class',
#   'United States',
#   'Pennsylvania',
#   'Philadelphia',
#   19134,
#   'East',
#   'Office Supplies',
#   'Labels'],
#  [975,
#   '2022-06-26',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Technology',
#   'Phones'],
#  [976,
#   '2023-11-01',
#   'Second Class',
#   'United States',
#   'New York',
#   'New York City',
#   10011,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [977,
#   '2023-02-03',
#   'Standard Class',
#   'United States',
#   'Oregon',
#   'Portland',
#   97206,
#   'West',
#   'Office Supplies',
#   'Binders'],
#  [978,
#   '2023-04-16',
#   'First Class',
#   'United States',
#   'Michigan',
#   'Detroit',
#   48205,
#   'Central',
#   'Technology',
#   'Machines'],
#  [979,
#   '2023-11-15',
#   'First Class',
#   'United States',
#   'North Carolina',
#   'Wilmington',
#   28403,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [980,
#   '2023-07-27',
#   'First Class',
#   'United States',
#   'Indiana',
#   'Columbus',
#   47201,
#   'Central',
#   'Office Supplies',
#   'Paper'],
#  [981,
#   '2022-04-25',
#   'Standard Class',
#   'United States',
#   'New York',
#   'New York City',
#   10035,
#   'East',
#   'Furniture',
#   'Chairs'],
#  [982,
#   '2023-03-31',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Louisville',
#   80027,
#   'West',
#   'Office Supplies',
#   'Art'],
#  [983,
#   '2023-02-01',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Louisville',
#   80027,
#   'West',
#   'Technology',
#   'Phones'],
#  [984,
#   '2022-10-16',
#   'Second Class',
#   'United States',
#   'Colorado',
#   'Louisville',
#   80027,
#   'West',
#   'Furniture',
#   'Chairs'],
#  [985,
#   '2023-03-27',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Pasadena',
#   77506,
#   'Central',
#   'Office Supplies',
#   'Labels'],
#  [986,
#   '2022-04-03',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Pasadena',
#   77506,
#   'Central',
#   'Office Supplies',
#   'Envelopes'],
#  [987,
#   '2023-12-25',
#   'Standard Class',
#   'United States',
#   'Texas',
#   'Pasadena',
#   77506,
#   'Central',
#   'Technology',
#   'Machines'],
#  [988,
#   '2023-10-28',
#   'Same Day',
#   'United States',
#   'Texas',
#   'Houston',
#   77041,
#   'Central',
#   'Office Supplies',
#   'Binders'],
#  [989,
#   '2023-11-14',
#   'Standard Class',
#   'United States',
#   'New York',
#   'Auburn',
#   13021,
#   'East',
#   'Furniture',
#   'Furnishings'],
#  [990,
#   '2023-02-19',
#   'Standard Class',
#   'United States',
#   'New York',
#   'Auburn',
#   13021,
#   'East',
#   'Office Supplies',
#   'Art'],
#  [991,
#   '2023-08-14',
#   'Second Class',
#   'United States',
#   'Florida',
#   'Jacksonville',
#   32216,
#   'South',
#   'Furniture',
#   'Chairs'],
#  [992,
#   '2023-07-16',
#   'First Class',
#   'United States',
#   'New York',
#   'New York City',
#   10024,
#   'East',
#   'Office Supplies',
#   'Binders'],
#  [993,
#   '2022-06-24',
#   'First Class',
#   'United States',
#   'California',
#   'San Jose',
#   95123,
#   'West',
#   'Office Supplies',
#   'Fasteners'],
#  [994,
#   '2022-06-29',
#   'First Class',
#   'United States',
#   'California',
#   'San Jose',
#   95123,
#   'West',
#   'Office Supplies',
#   'Paper'],
#  [995,
#   '2023-03-24',
#   'Standard Class',
#   'United States',
#   'Virginia',
#   'Virginia Beach',
#   23464,
#   'South',
#   'Office Supplies',
#   'Binders'],
#  [996,
#   '2022-02-10',
#   'Standard Class',
#   'United States',
#   'Virginia',
#   'Virginia Beach',
#   23464,
#   'South',
#   'Technology',
#   'Phones'],
#  [997,
#   '2023-03-25',
#   'Standard Class',
#   'United States',
#   'Kentucky',
#   'Henderson',
#   42420,
#   'South',
#   'Office Supplies',
#   'Envelopes'],
#  [998,
#   '2023-02-17',
#   'Standard Class',
#   'United States',
#   'Kentucky',
#   'Henderson',
#   42420,
#   'South',
#   'Office Supplies',
#   'Storage'],
#  [999,
#   '2023-11-25',
#   'Standard Class',
#   'United States',
#   'Kentucky',
#   'Henderson',
#   42420,
#   'South',
#   'Furniture',
#   'Furnishings'],
#  [1000,
#   '2023-09-05',
#   'Standard Class',
#   'United States',
#   'Kentucky',
#   'Henderson',
#   42420,
#   'South',
#   'Furniture',
#   'Furnishings'],
#  ...]

# %%
for i in file:
    data.execute(query,i)
mydb.commit()

# %%
# df2 insert into mysql

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sale_price  profit
# 0                    2       5.2       254.8    14.8
# 1                    3      21.9       708.1   108.1
# 2                    5       0.5         9.5    -0.5
# 3                    2      19.2       940.8   160.8
# 4                    5       1.0        19.0    -1.0
# ...                ...       ...         ...     ...
# 9989                 4       1.2        28.8    -1.2
# 9990                 4       3.6        86.4    16.4
# 9991                 2       5.2       254.8    34.8
# 9992                 3       0.9        29.1    -0.9
# 9993                 3       7.2       232.8    22.8
#
# [9994 rows x 19 columns]

# %%
df2=df[['order_id','segment','product_id','cost_price','list_price','quantity','discount_percent','discount','sale_price','profit']]
df2
# Out:
#       order_id    segment       product_id  cost_price  list_price  quantity  \
# 0            1   Consumer  FUR-BO-10001798         240         260         2
# 1            2   Consumer  FUR-CH-10000454         600         730         3
# 2            3  Corporate  OFF-LA-10000240          10          10         2
# 3            4   Consumer  FUR-TA-10000577         780         960         5
# 4            5   Consumer  OFF-ST-10000760          20          20         2
# ...        ...        ...              ...         ...         ...       ...
# 9989      9990   Consumer  FUR-FU-10001889          30          30         3
# 9990      9991   Consumer  FUR-FU-10000747          70          90         2
# 9991      9992   Consumer  TEC-PH-10003645         220         260         2
# 9992      9993   Consumer  OFF-PA-10004041          30          30         4
# 9993      9994   Consumer  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  sale_price  profit
# 0                    2       5.2       254.8    14.8
# 1                    3      21.9       708.1   108.1
# 2                    5       0.5         9.5    -0.5
# 3                    2      19.2       940.8   160.8
# 4                    5       1.0        19.0    -1.0
# ...                ...       ...         ...     ...
# 9989                 4       1.2        28.8    -1.2
# 9990                 4       3.6        86.4    16.4
# 9991                 2       5.2       254.8    34.8
# 9992                 3       0.9        29.1    -0.9
# 9993                 3       7.2       232.8    22.8
#
# [9994 rows x 10 columns]

# %%
data.execute("use retail_orders")

# %%
data.execute("""
CREATE TABLE table_05
(
    order_id INT,
    segment VARCHAR(255),
    product_id VARCHAR(255),
    cost_price DECIMAL(10, 2),
    list_price DECIMAL(10, 2),
    quantity INT,
    discount_percent DECIMAL(5, 2),
    discount DECIMAL(10, 2),
    sale_price DECIMAL(10, 2),
    profit DECIMAL(10, 2),
    PRIMARY KEY (order_id, product_id),
    FOREIGN KEY (order_id) REFERENCES table_1(order_id)
);
""")

# %%
query = 'INSERT IGNORE INTO table_05(order_id,segment,product_id,cost_price,list_price,quantity,discount_percent,discount,sale_price,profit) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'

# %%
data_file = df2.values.tolist()
data_file
# Out:
# [[1,
#   'Consumer',
#   'FUR-BO-10001798',
#   240,
#   260,
#   2,
#   2,
#   5.2,
#   254.8,
#   14.800000000000011],
#  [2,
#   'Consumer',
#   'FUR-CH-10000454',
#   600,
#   730,
#   3,
#   3,
#   21.900000000000002,
#   708.1,
#   108.10000000000002],
#  [3, 'Corporate', 'OFF-LA-10000240', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [4,
#   'Consumer',
#   'FUR-TA-10000577',
#   780,
#   960,
#   5,
#   2,
#   19.2,
#   940.8,
#   160.79999999999995],
#  [5, 'Consumer', 'OFF-ST-10000760', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [6, 'Consumer', 'FUR-FU-10001487', 50, 50, 7, 3, 1.5, 48.5, -1.5],
#  [7,
#   'Consumer',
#   'OFF-AR-10002833',
#   10,
#   10,
#   4,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [8, 'Consumer', 'TEC-PH-10002275', 860, 910, 6, 5, 45.5, 864.5, 4.5],
#  [9,
#   'Consumer',
#   'OFF-BI-10003910',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [10,
#   'Consumer',
#   'OFF-AP-10002892',
#   90,
#   110,
#   5,
#   3,
#   3.3000000000000003,
#   106.7,
#   16.700000000000003],
#  [11,
#   'Consumer',
#   'FUR-TA-10001539',
#   1470,
#   1710,
#   9,
#   3,
#   51.300000000000004,
#   1658.7,
#   188.70000000000005],
#  [12,
#   'Consumer',
#   'TEC-PH-10002033',
#   750,
#   910,
#   4,
#   3,
#   27.3,
#   882.7,
#   132.70000000000005],
#  [13,
#   'Consumer',
#   'OFF-PA-10002365',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [14,
#   'Consumer',
#   'OFF-BI-10003656',
#   360,
#   410,
#   3,
#   2,
#   8.2,
#   401.8,
#   41.80000000000001],
#  [15, 'Home Office', 'OFF-AP-10002311', 60, 70, 5, 5, 3.5, 66.5, 6.5],
#  [16, 'Home Office', 'OFF-BI-10000756', 0, 0, 3, 5, 0.0, 0.0, 0.0],
#  [17,
#   'Consumer',
#   'OFF-ST-10004186',
#   610,
#   670,
#   6,
#   3,
#   20.1,
#   649.9,
#   39.89999999999998],
#  [18,
#   'Consumer',
#   'OFF-ST-10000107',
#   60,
#   60,
#   2,
#   4,
#   2.4,
#   57.6,
#   -2.3999999999999986],
#  [19,
#   'Consumer',
#   'OFF-AR-10003056',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [20,
#   'Consumer',
#   'TEC-PH-10001949',
#   170,
#   210,
#   3,
#   3,
#   6.3,
#   203.7,
#   33.69999999999999],
#  [21,
#   'Consumer',
#   'OFF-BI-10002215',
#   20,
#   20,
#   4,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [22,
#   'Corporate',
#   'OFF-AR-10000246',
#   20,
#   20,
#   7,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [23,
#   'Corporate',
#   'OFF-AP-10001492',
#   50,
#   60,
#   7,
#   3,
#   1.8,
#   58.2,
#   8.200000000000003],
#  [24,
#   'Consumer',
#   'FUR-CH-10002774',
#   60,
#   70,
#   2,
#   4,
#   2.8000000000000003,
#   67.2,
#   7.200000000000003],
#  [25, 'Consumer', 'FUR-TA-10000577', 900, 1040, 3, 5, 52.0, 988.0, 88.0],
#  [26, 'Consumer', 'OFF-BI-10001634', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [27,
#   'Consumer',
#   'TEC-AC-10003027',
#   80,
#   90,
#   3,
#   3,
#   2.7,
#   87.3,
#   7.299999999999997],
#  [28,
#   'Consumer',
#   'FUR-BO-10004834',
#   2740,
#   3080,
#   7,
#   3,
#   92.4,
#   2987.6,
#   247.5999999999999],
#  [29, 'Consumer', 'OFF-BI-10000474', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [30,
#   'Consumer',
#   'FUR-FU-10004848',
#   100,
#   120,
#   3,
#   4,
#   4.8,
#   115.2,
#   15.200000000000003],
#  [31, 'Consumer', 'OFF-EN-10001509', 0, 0, 2, 5, 0.0, 0.0, 0.0],
#  [32,
#   'Consumer',
#   'OFF-AR-10004042',
#   70,
#   90,
#   6,
#   4,
#   3.6,
#   86.4,
#   16.400000000000006],
#  [33, 'Consumer', 'OFF-BI-10001525', 10, 10, 6, 5, 0.5, 9.5, -0.5],
#  [34,
#   'Consumer',
#   'OFF-AR-10001683',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [35,
#   'Home Office',
#   'OFF-PA-10000249',
#   30,
#   30,
#   3,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [36, 'Corporate', 'TEC-PH-10004977', 1020, 1100, 7, 5, 55.0, 1045.0, 25.0],
#  [37,
#   'Corporate',
#   'FUR-FU-10003664',
#   180,
#   190,
#   5,
#   4,
#   7.6000000000000005,
#   182.4,
#   2.4000000000000057],
#  [38,
#   'Home Office',
#   'OFF-EN-10002986',
#   90,
#   110,
#   9,
#   2,
#   2.2,
#   107.8,
#   17.799999999999997],
#  [39,
#   'Home Office',
#   'FUR-BO-10002545',
#   460,
#   530,
#   3,
#   2,
#   10.6,
#   519.4,
#   59.39999999999998],
#  [40,
#   'Home Office',
#   'FUR-CH-10004218',
#   200,
#   210,
#   3,
#   2,
#   4.2,
#   205.8,
#   5.800000000000011],
#  [41, 'Home Office', 'TEC-PH-10000486', 350, 370, 4, 5, 18.5, 351.5, 1.5],
#  [42, 'Corporate', 'TEC-PH-10004093', 140, 150, 4, 3, 4.5, 145.5, 5.5],
#  [43, 'Corporate', 'OFF-ST-10003479', 70, 80, 2, 5, 4.0, 76.0, 6.0],
#  [44, 'Corporate', 'OFF-ST-10003282', 90, 100, 2, 4, 4.0, 96.0, 6.0],
#  [45, 'Corporate', 'TEC-AC-10000171', 40, 50, 2, 2, 1.0, 49.0, 9.0],
#  [46, 'Corporate', 'OFF-BI-10003291', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [47,
#   'Consumer',
#   'OFF-ST-10001713',
#   180,
#   210,
#   4,
#   4,
#   8.4,
#   201.6,
#   21.599999999999994],
#  [48, 'Consumer', 'TEC-AC-10002167', 50, 50, 3, 5, 2.5, 47.5, -2.5],
#  [49,
#   'Consumer',
#   'TEC-PH-10003988',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [50,
#   'Consumer',
#   'OFF-BI-10004410',
#   30,
#   40,
#   6,
#   4,
#   1.6,
#   38.4,
#   8.399999999999999],
#  [51,
#   'Consumer',
#   'OFF-LA-10002762',
#   70,
#   80,
#   6,
#   4,
#   3.2,
#   76.8,
#   6.799999999999997],
#  [52,
#   'Consumer',
#   'FUR-FU-10001706',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [53, 'Consumer', 'FUR-CH-10003061', 70, 90, 1, 5, 4.5, 85.5, 15.5],
#  [54,
#   'Corporate',
#   'OFF-FA-10000304',
#   20,
#   20,
#   7,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [55,
#   'Corporate',
#   'TEC-PH-10002447',
#   850,
#   1030,
#   5,
#   4,
#   41.2,
#   988.8,
#   138.79999999999995],
#  [56, 'Consumer', 'OFF-ST-10000604', 200, 210, 6, 5, 10.5, 199.5, -0.5],
#  [57, 'Consumer', 'OFF-PA-10001569', 30, 30, 5, 5, 1.5, 28.5, -1.5],
#  [58,
#   'Consumer',
#   'FUR-CH-10003968',
#   290,
#   320,
#   5,
#   2,
#   6.4,
#   313.6,
#   23.600000000000023],
#  [59,
#   'Consumer',
#   'OFF-PA-10000587',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [60, 'Consumer', 'TEC-AC-10002167', 20, 30, 2, 5, 1.5, 28.5, 8.5],
#  [61, 'Consumer', 'OFF-BI-10001460', 40, 50, 4, 2, 1.0, 49.0, 9.0],
#  [62, 'Consumer', 'OFF-AR-10001868', 0, 0, 1, 5, 0.0, 0.0, 0.0],
#  [63,
#   'Consumer',
#   'TEC-AC-10004633',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [64,
#   'Consumer',
#   'OFF-BI-10001078',
#   20,
#   30,
#   6,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [65, 'Consumer', 'OFF-PA-10003892', 130, 150, 3, 5, 7.5, 142.5, 12.5],
#  [66,
#   'Consumer',
#   'FUR-FU-10000397',
#   70,
#   80,
#   4,
#   2,
#   1.6,
#   78.4,
#   8.400000000000006],
#  [67, 'Home Office', 'FUR-CH-10001146', 180, 210, 5, 5, 10.5, 199.5, 19.5],
#  [68,
#   'Corporate',
#   'OFF-AR-10002671',
#   940,
#   1110,
#   8,
#   3,
#   33.3,
#   1076.7,
#   136.70000000000005],
#  [69,
#   'Corporate',
#   'TEC-PH-10002726',
#   160,
#   170,
#   4,
#   3,
#   5.1000000000000005,
#   164.9,
#   4.900000000000006],
#  [70,
#   'Consumer',
#   'OFF-PA-10000482',
#   70,
#   80,
#   2,
#   2,
#   1.6,
#   78.4,
#   8.400000000000006],
#  [71, 'Consumer', 'OFF-BI-10004654', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [72,
#   'Consumer',
#   'OFF-PA-10004675',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [73,
#   'Consumer',
#   'FUR-CH-10000513',
#   790,
#   830,
#   8,
#   2,
#   16.6,
#   813.4,
#   23.399999999999977],
#  [74, 'Consumer', 'FUR-FU-10003708', 90, 100, 2, 3, 3.0, 97.0, 7.0],
#  [75,
#   'Consumer',
#   'OFF-ST-10004123',
#   60,
#   70,
#   1,
#   2,
#   1.4000000000000001,
#   68.6,
#   8.599999999999994],
#  [76, 'Corporate', 'OFF-BI-10004182', 0, 0, 3, 4, 0.0, 0.0, 0.0],
#  [77,
#   'Corporate',
#   'FUR-FU-10000260',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [78,
#   'Corporate',
#   'OFF-ST-10000615',
#   20,
#   30,
#   3,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [79,
#   'Consumer',
#   'FUR-FU-10003194',
#   20,
#   20,
#   5,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [80,
#   'Corporate',
#   'OFF-AP-10002118',
#   190,
#   210,
#   1,
#   3,
#   6.3,
#   203.7,
#   13.699999999999989],
#  [81,
#   'Corporate',
#   'OFF-BI-10002309',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [82, 'Consumer', 'OFF-AR-10002053', 10, 10, 5, 5, 0.5, 9.5, -0.5],
#  [83,
#   'Consumer',
#   'OFF-ST-10002370',
#   20,
#   20,
#   1,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [84, 'Corporate', 'OFF-EN-10000927', 180, 200, 7, 3, 6.0, 194.0, 14.0],
#  [85,
#   'Home Office',
#   'OFF-ST-10003656',
#   210,
#   230,
#   3,
#   2,
#   4.6000000000000005,
#   225.4,
#   15.400000000000006],
#  [86, 'Consumer', 'FUR-CH-10000863', 260, 300, 2, 5, 15.0, 285.0, 25.0],
#  [87, 'Consumer', 'TEC-AC-10001998', 20, 20, 1, 5, 1.0, 19.0, -1.0],
#  [88, 'Consumer', 'OFF-LA-10000134', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [89, 'Home Office', 'OFF-ST-10003442', 140, 160, 7, 5, 8.0, 152.0, 12.0],
#  [90,
#   'Corporate',
#   'OFF-AR-10004930',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [91,
#   'Corporate',
#   'TEC-PH-10004093',
#   60,
#   70,
#   2,
#   2,
#   1.4000000000000001,
#   68.6,
#   8.599999999999994],
#  [92,
#   'Corporate',
#   'OFF-PA-10000304',
#   10,
#   10,
#   1,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [93,
#   'Consumer',
#   'OFF-PA-10003177',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [94, 'Consumer', 'FUR-FU-10003799', 50, 50, 3, 5, 2.5, 47.5, -2.5],
#  [95,
#   'Consumer',
#   'OFF-BI-10002852',
#   20,
#   30,
#   2,
#   3,
#   0.9,
#   29.1,
#   9.100000000000001],
#  [96,
#   'Home Office',
#   'OFF-BI-10004738',
#   10,
#   10,
#   1,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [97, 'Home Office', 'FUR-FU-10000629', 80, 100, 7, 5, 5.0, 95.0, 15.0],
#  [98, 'Consumer', 'OFF-BI-10001721', 40, 50, 3, 4, 2.0, 48.0, 8.0],
#  [99,
#   'Corporate',
#   'OFF-AP-10000358',
#   70,
#   80,
#   6,
#   3,
#   2.4,
#   77.6,
#   7.599999999999994],
#  [100,
#   'Home Office',
#   'OFF-PA-10003256',
#   60,
#   60,
#   7,
#   3,
#   1.8,
#   58.2,
#   -1.7999999999999972],
#  [101, 'Home Office', 'TEC-AC-10001767', 80, 100, 3, 5, 5.0, 95.0, 15.0],
#  [102, 'Home Office', 'OFF-BI-10002609', 0, 0, 3, 3, 0.0, 0.0, 0.0],
#  [103,
#   'Consumer',
#   'OFF-PA-10004040',
#   20,
#   20,
#   4,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [104,
#   'Consumer',
#   'TEC-AC-10001552',
#   220,
#   240,
#   6,
#   3,
#   7.2,
#   232.8,
#   12.800000000000011],
#  [105, 'Consumer', 'FUR-FU-10004006', 90, 100, 3, 5, 5.0, 95.0, 5.0],
#  [106, 'Consumer', 'OFF-BI-10002794', 30, 40, 3, 5, 2.0, 38.0, 8.0],
#  [107, 'Consumer', 'TEC-AC-10003499', 60, 70, 8, 5, 3.5, 66.5, 6.5],
#  [108,
#   'Consumer',
#   'TEC-PH-10002844',
#   30,
#   30,
#   1,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [109, 'Consumer', 'OFF-AR-10000390', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [110,
#   'Home Office',
#   'TEC-AC-10000844',
#   290,
#   340,
#   5,
#   2,
#   6.8,
#   333.2,
#   43.19999999999999],
#  [111,
#   'Corporate',
#   'FUR-FU-10001934',
#   30,
#   40,
#   2,
#   2,
#   0.8,
#   39.2,
#   9.200000000000003],
#  [112,
#   'Consumer',
#   'OFF-AR-10000380',
#   70,
#   80,
#   2,
#   3,
#   2.4,
#   77.6,
#   7.599999999999994],
#  [113,
#   'Consumer',
#   'OFF-BI-10003981',
#   30,
#   30,
#   6,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [114,
#   'Consumer',
#   'OFF-FA-10000621',
#   40,
#   40,
#   14,
#   2,
#   0.8,
#   39.2,
#   -0.7999999999999972],
#  [115, 'Consumer', 'OFF-EN-10002600', 0, 0, 2, 4, 0.0, 0.0, 0.0],
#  [116,
#   'Consumer',
#   'OFF-PA-10004965',
#   20,
#   20,
#   3,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [117, 'Consumer', 'OFF-EN-10002504', 120, 130, 6, 5, 6.5, 123.5, 3.5],
#  [118,
#   'Consumer',
#   'FUR-TA-10001768',
#   720,
#   790,
#   3,
#   4,
#   31.6,
#   758.4,
#   38.39999999999998],
#  [119, 'Corporate', 'OFF-BI-10003650', 140, 160, 1, 5, 8.0, 152.0, 12.0],
#  [120, 'Consumer', 'FUR-FU-10002157', 50, 50, 3, 3, 1.5, 48.5, -1.5],
#  [121,
#   'Consumer',
#   'OFF-BI-10003910',
#   20,
#   30,
#   4,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [122,
#   'Consumer',
#   'OFF-ST-10000777',
#   190,
#   230,
#   6,
#   2,
#   4.6000000000000005,
#   225.4,
#   35.400000000000006],
#  [123,
#   'Consumer',
#   'OFF-EN-10002500',
#   110,
#   120,
#   9,
#   4,
#   4.8,
#   115.2,
#   5.200000000000003],
#  [124,
#   'Consumer',
#   'TEC-PH-10003875',
#   60,
#   70,
#   7,
#   2,
#   1.4000000000000001,
#   68.6,
#   8.599999999999994],
#  [125, 'Home Office', 'FUR-CH-10004063', 550, 600, 3, 3, 18.0, 582.0, 32.0],
#  [126,
#   'Consumer',
#   'FUR-TA-10004534',
#   540,
#   620,
#   6,
#   4,
#   24.8,
#   595.2,
#   55.200000000000045],
#  [127, 'Consumer', 'OFF-BI-10003274', 0, 0, 2, 4, 0.0, 0.0, 0.0],
#  [128,
#   'Consumer',
#   'OFF-ST-10002974',
#   200,
#   240,
#   7,
#   4,
#   9.6,
#   230.4,
#   30.400000000000006],
#  [129,
#   'Home Office',
#   'FUR-CH-10001146',
#   70,
#   80,
#   2,
#   2,
#   1.6,
#   78.4,
#   8.400000000000006],
#  [130,
#   'Home Office',
#   'FUR-FU-10003773',
#   220,
#   240,
#   3,
#   4,
#   9.6,
#   230.4,
#   10.400000000000006],
#  [131,
#   'Corporate',
#   'TEC-PH-10002293',
#   50,
#   60,
#   5,
#   3,
#   1.8,
#   58.2,
#   8.200000000000003],
#  [132,
#   'Corporate',
#   'OFF-PA-10002377',
#   80,
#   80,
#   2,
#   4,
#   3.2,
#   76.8,
#   -3.200000000000003],
#  [133, 'Corporate', 'OFF-FA-10002780', 20, 20, 9, 5, 1.0, 19.0, -1.0],
#  [134,
#   'Consumer',
#   'OFF-PA-10001804',
#   20,
#   20,
#   3,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [135, 'Consumer', 'OFF-PA-10001736', 30, 40, 1, 5, 2.0, 38.0, 8.0],
#  [136, 'Consumer', 'OFF-AR-10001149', 10, 10, 4, 5, 0.5, 9.5, -0.5],
#  [137, 'Consumer', 'OFF-FA-10002988', 0, 0, 2, 5, 0.0, 0.0, 0.0],
#  [138,
#   'Consumer',
#   'OFF-BI-10004781',
#   70,
#   80,
#   3,
#   2,
#   1.6,
#   78.4,
#   8.400000000000006],
#  [139, 'Consumer', 'OFF-SU-10001218', 60, 70, 6, 5, 3.5, 66.5, 6.5],
#  [140,
#   'Consumer',
#   'FUR-FU-10001706',
#   40,
#   40,
#   14,
#   2,
#   0.8,
#   39.2,
#   -0.7999999999999972],
#  [141,
#   'Corporate',
#   'FUR-FU-10004848',
#   60,
#   80,
#   2,
#   2,
#   1.6,
#   78.4,
#   18.400000000000006],
#  [142,
#   'Corporate',
#   'OFF-AR-10000940',
#   10,
#   10,
#   3,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [143,
#   'Corporate',
#   'OFF-EN-10004030',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [144, 'Corporate', 'OFF-PA-10004327', 130, 140, 3, 5, 7.0, 133.0, 3.0],
#  [145,
#   'Consumer',
#   'OFF-AP-10001058',
#   780,
#   840,
#   3,
#   2,
#   16.8,
#   823.2,
#   43.200000000000045],
#  [146,
#   'Consumer',
#   'OFF-ST-10003656',
#   600,
#   670,
#   7,
#   3,
#   20.1,
#   649.9,
#   49.89999999999998],
#  [147,
#   'Home Office',
#   'FUR-FU-10000521',
#   80,
#   90,
#   4,
#   4,
#   3.6,
#   86.4,
#   6.400000000000006],
#  [148,
#   'Corporate',
#   'TEC-PH-10000215',
#   350,
#   380,
#   11,
#   4,
#   15.200000000000001,
#   364.8,
#   14.800000000000011],
#  [149, 'Corporate', 'TEC-PH-10001448', 140, 150, 3, 5, 7.5, 142.5, 2.5],
#  [150, 'Corporate', 'FUR-CH-10000454', 1580, 1950, 8, 3, 58.5, 1891.5, 311.5],
#  [151,
#   'Corporate',
#   'OFF-BI-10002735',
#   150,
#   170,
#   5,
#   4,
#   6.8,
#   163.2,
#   13.199999999999989],
#  [152, 'Home Office', 'OFF-AP-10000326', 140, 160, 5, 5, 8.0, 152.0, 12.0],
#  [153, 'Home Office', 'TEC-PH-10001254', 160, 200, 2, 2, 4.0, 196.0, 36.0],
#  [154,
#   'Corporate',
#   'OFF-PA-10001950',
#   50,
#   60,
#   7,
#   4,
#   2.4,
#   57.6,
#   7.600000000000001],
#  [155,
#   'Corporate',
#   'OFF-PA-10002254',
#   100,
#   110,
#   4,
#   4,
#   4.4,
#   105.6,
#   5.599999999999994],
#  [156,
#   'Corporate',
#   'OFF-ST-10001590',
#   60,
#   80,
#   6,
#   4,
#   3.2,
#   76.8,
#   16.799999999999997],
#  [157,
#   'Home Office',
#   'OFF-AR-10001547',
#   10,
#   10,
#   3,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [158,
#   'Consumer',
#   'FUR-CH-10004063',
#   380,
#   460,
#   2,
#   2,
#   9.200000000000001,
#   450.8,
#   70.80000000000001],
#  [159,
#   'Consumer',
#   'OFF-LA-10002475',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [160, 'Consumer', 'TEC-PH-10004536', 870, 940, 7, 5, 47.0, 893.0, 23.0],
#  [161,
#   'Consumer',
#   'OFF-PA-10002751',
#   10,
#   10,
#   1,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [162, 'Consumer', 'TEC-AC-10003657', 40, 50, 2, 5, 2.5, 47.5, 7.5],
#  [163,
#   'Consumer',
#   'OFF-EN-10001990',
#   30,
#   30,
#   5,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [164,
#   'Consumer',
#   'OFF-BI-10004002',
#   20,
#   30,
#   2,
#   3,
#   0.9,
#   29.1,
#   9.100000000000001],
#  [165, 'Consumer', 'OFF-AR-10004441', 10, 10, 3, 5, 0.5, 9.5, -0.5],
#  [166,
#   'Consumer',
#   'TEC-MA-10000822',
#   6850,
#   8160,
#   8,
#   4,
#   326.40000000000003,
#   7833.6,
#   983.6000000000004],
#  [167,
#   'Consumer',
#   'OFF-ST-10000991',
#   250,
#   280,
#   3,
#   4,
#   11.200000000000001,
#   268.8,
#   18.80000000000001],
#  [168,
#   'Consumer',
#   'FUR-CH-10004287',
#   1620,
#   1740,
#   9,
#   4,
#   69.60000000000001,
#   1670.4,
#   50.40000000000009],
#  [169,
#   'Consumer',
#   'OFF-AR-10002656',
#   30,
#   30,
#   6,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [170,
#   'Consumer',
#   'OFF-AP-10002518',
#   150,
#   180,
#   5,
#   2,
#   3.6,
#   176.4,
#   26.400000000000006],
#  [171, 'Consumer', 'TEC-PH-10003931', 120, 140, 3, 5, 7.0, 133.0, 13.0],
#  [172,
#   'Consumer',
#   'OFF-PA-10000659',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [173,
#   'Consumer',
#   'OFF-PA-10001144',
#   100,
#   110,
#   2,
#   4,
#   4.4,
#   105.6,
#   5.599999999999994],
#  [174,
#   'Consumer',
#   'FUR-CH-10003817',
#   290,
#   340,
#   7,
#   2,
#   6.8,
#   333.2,
#   43.19999999999999],
#  [175, 'Corporate', 'OFF-AP-10000891', 50, 50, 2, 4, 2.0, 48.0, -2.0],
#  [176, 'Corporate', 'OFF-LA-10003148', 20, 20, 4, 5, 1.0, 19.0, -1.0],
#  [177, 'Consumer', 'OFF-AP-10002684', 90, 100, 4, 2, 2.0, 98.0, 8.0],
#  [178, 'Consumer', 'FUR-CH-10004698', 370, 400, 7, 5, 20.0, 380.0, 10.0],
#  [179,
#   'Consumer',
#   'OFF-SU-10002189',
#   20,
#   20,
#   5,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [180, 'Home Office', 'OFF-AR-10001940', 0, 0, 1, 5, 0.0, 0.0, 0.0],
#  [181, 'Corporate', 'OFF-ST-10003455', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [182,
#   'Corporate',
#   'TEC-AC-10004659',
#   380,
#   410,
#   7,
#   3,
#   12.3,
#   397.7,
#   17.69999999999999],
#  [183, 'Home Office', 'TEC-PH-10003273', 470, 500, 4, 5, 25.0, 475.0, 5.0],
#  [184, 'Home Office', 'TEC-PH-10004896', 140, 150, 5, 2, 3.0, 147.0, 7.0],
#  [185, 'Home Office', 'TEC-AC-10002345', 30, 30, 2, 5, 1.5, 28.5, -1.5],
#  [186,
#   'Consumer',
#   'OFF-BI-10001890',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [187,
#   'Home Office',
#   'TEC-AC-10002323',
#   160,
#   180,
#   8,
#   3,
#   5.4,
#   174.6,
#   14.599999999999994],
#  [188,
#   'Corporate',
#   'OFF-ST-10001328',
#   40,
#   40,
#   3,
#   4,
#   1.6,
#   38.4,
#   -1.6000000000000014],
#  [189,
#   'Corporate',
#   'OFF-PA-10001950',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [190, 'Home Office', 'FUR-BO-10002613', 820, 900, 4, 3, 27.0, 873.0, 53.0],
#  [191,
#   'Home Office',
#   'TEC-PH-10001552',
#   60,
#   70,
#   6,
#   4,
#   2.8000000000000003,
#   67.2,
#   7.200000000000003],
#  [192, 'Home Office', 'OFF-PA-10000061', 50, 50, 8, 5, 2.5, 47.5, -2.5],
#  [193,
#   'Home Office',
#   'FUR-BO-10002545',
#   520,
#   630,
#   3,
#   2,
#   12.6,
#   617.4,
#   97.39999999999998],
#  [194,
#   'Home Office',
#   'OFF-AR-10003514',
#   20,
#   20,
#   5,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [195,
#   'Corporate',
#   'OFF-EN-10001509',
#   10,
#   10,
#   7,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [196, 'Consumer', 'OFF-AR-10004685', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [197,
#   'Consumer',
#   'OFF-AR-10004027',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [198, 'Home Office', 'OFF-ST-10001414', 40, 50, 3, 5, 2.5, 47.5, 7.5],
#  [199, 'Corporate', 'OFF-BI-10000343', 0, 0, 2, 5, 0.0, 0.0, 0.0],
#  [200,
#   'Corporate',
#   'OFF-PA-10002749',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [201, 'Consumer', 'OFF-PA-10002666', 20, 20, 3, 5, 1.0, 19.0, -1.0],
#  [202,
#   'Consumer',
#   'FUR-TA-10004289',
#   200,
#   220,
#   2,
#   3,
#   6.6000000000000005,
#   213.4,
#   13.400000000000006],
#  [203, 'Consumer', 'OFF-AP-10003622', 0, 0, 1, 5, 0.0, 0.0, 0.0],
#  [204,
#   'Consumer',
#   'OFF-AP-10003217',
#   60,
#   70,
#   2,
#   2,
#   1.4000000000000001,
#   68.6,
#   8.599999999999994],
#  [205,
#   'Corporate',
#   'FUR-FU-10002960',
#   40,
#   40,
#   7,
#   3,
#   1.2,
#   38.8,
#   -1.2000000000000028],
#  [206,
#   'Consumer',
#   'TEC-PH-10001918',
#   370,
#   440,
#   4,
#   3,
#   13.200000000000001,
#   426.8,
#   56.80000000000001],
#  [207,
#   'Consumer',
#   'OFF-ST-10000642',
#   70,
#   80,
#   4,
#   4,
#   3.2,
#   76.8,
#   6.799999999999997],
#  [208,
#   'Consumer',
#   'TEC-PH-10001700',
#   120,
#   130,
#   2,
#   3,
#   3.9,
#   126.1,
#   6.099999999999994],
#  [209,
#   'Consumer',
#   'OFF-BI-10003274',
#   20,
#   20,
#   4,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [210, 'Consumer', 'OFF-FA-10000134', 50, 50, 9, 2, 1.0, 49.0, -1.0],
#  [211, 'Consumer', 'OFF-ST-10001522', 80, 90, 1, 5, 4.5, 85.5, 5.5],
#  [212,
#   'Corporate',
#   'TEC-AC-10001266',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [213,
#   'Corporate',
#   'OFF-LA-10004544',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [214, 'Corporate', 'FUR-BO-10004695', 390, 450, 5, 5, 22.5, 427.5, 37.5],
#  [215,
#   'Corporate',
#   'TEC-PH-10002844',
#   50,
#   60,
#   3,
#   3,
#   1.8,
#   58.2,
#   8.200000000000003],
#  [216,
#   'Corporate',
#   'TEC-MA-10000864',
#   1040,
#   1190,
#   9,
#   4,
#   47.6,
#   1142.4,
#   102.40000000000009],
#  [217, 'Corporate', 'TEC-AC-10000109', 80, 90, 2, 5, 4.5, 85.5, 5.5],
#  [218,
#   'Consumer',
#   'OFF-ST-10001328',
#   80,
#   90,
#   6,
#   3,
#   2.7,
#   87.3,
#   7.299999999999997],
#  [219, 'Consumer', 'TEC-PH-10002563', 250, 300, 3, 4, 12.0, 288.0, 38.0],
#  [220,
#   'Consumer',
#   'OFF-FA-10000585',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [221,
#   'Consumer',
#   'OFF-PA-10004000',
#   20,
#   20,
#   6,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [222,
#   'Consumer',
#   'OFF-BI-10002852',
#   20,
#   20,
#   4,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [223,
#   'Consumer',
#   'FUR-FU-10000087',
#   60,
#   70,
#   4,
#   3,
#   2.1,
#   67.9,
#   7.900000000000006],
#  [224,
#   'Consumer',
#   'TEC-MA-10001148',
#   410,
#   480,
#   4,
#   4,
#   19.2,
#   460.8,
#   50.80000000000001],
#  [225,
#   'Consumer',
#   'OFF-AR-10001958',
#   30,
#   30,
#   2,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [226, 'Corporate', 'OFF-AR-10001026', 0, 0, 1, 2, 0.0, 0.0, 0.0],
#  [227,
#   'Corporate',
#   'FUR-TA-10003748',
#   510,
#   620,
#   5,
#   2,
#   12.4,
#   607.6,
#   97.60000000000002],
#  [228,
#   'Corporate',
#   'OFF-ST-10002485',
#   20,
#   20,
#   1,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [229,
#   'Consumer',
#   'FUR-CH-10004860',
#   130,
#   160,
#   2,
#   2,
#   3.2,
#   156.8,
#   26.80000000000001],
#  [230,
#   'Consumer',
#   'FUR-CH-10004477',
#   360,
#   390,
#   8,
#   2,
#   7.8,
#   382.2,
#   22.19999999999999],
#  [231, 'Corporate', 'OFF-BI-10001679', 20, 20, 7, 5, 1.0, 19.0, -1.0],
#  [232,
#   'Home Office',
#   'FUR-TA-10001705',
#   210,
#   230,
#   2,
#   4,
#   9.200000000000001,
#   220.8,
#   10.800000000000011],
#  [233,
#   'Home Office',
#   'FUR-TA-10003473',
#   510,
#   620,
#   3,
#   4,
#   24.8,
#   595.2,
#   85.20000000000005],
#  [234,
#   'Home Office',
#   'OFF-BI-10001679',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [235, 'Home Office', 'FUR-FU-10004017', 250, 260, 3, 5, 13.0, 247.0, -3.0],
#  [236,
#   'Home Office',
#   'TEC-AC-10003832',
#   500,
#   620,
#   3,
#   4,
#   24.8,
#   595.2,
#   95.20000000000005],
#  [237,
#   'Corporate',
#   'OFF-PA-10002479',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [238,
#   'Consumer',
#   'OFF-PA-10003349',
#   30,
#   30,
#   5,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [239,
#   'Consumer',
#   'FUR-FU-10000576',
#   340,
#   420,
#   5,
#   2,
#   8.4,
#   411.6,
#   71.60000000000002],
#  [240,
#   'Consumer',
#   'FUR-FU-10004351',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [241,
#   'Consumer',
#   'TEC-PH-10000011',
#   30,
#   30,
#   2,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [242,
#   'Consumer',
#   'FUR-TA-10002607',
#   150,
#   180,
#   5,
#   3,
#   5.4,
#   174.6,
#   24.599999999999994],
#  [243, 'Consumer', 'FUR-FU-10002505', 0, 0, 3, 4, 0.0, 0.0, 0.0],
#  [244,
#   'Consumer',
#   'OFF-AR-10004685',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [245,
#   'Home Office',
#   'FUR-CH-10004063',
#   1620,
#   2000,
#   7,
#   2,
#   40.0,
#   1960.0,
#   340.0],
#  [246,
#   'Home Office',
#   'OFF-ST-10002276',
#   150,
#   170,
#   2,
#   4,
#   6.8,
#   163.2,
#   13.199999999999989],
#  [247, 'Home Office', 'OFF-PA-10004082', 40, 50, 6, 5, 2.5, 47.5, 7.5],
#  [248, 'Home Office', 'OFF-AP-10002945', 1380, 1500, 5, 5, 75.0, 1425.0, 45.0],
#  [249,
#   'Home Office',
#   'OFF-PA-10000061',
#   20,
#   30,
#   4,
#   3,
#   0.9,
#   29.1,
#   9.100000000000001],
#  [250, 'Consumer', 'FUR-CH-10002965', 300, 320, 2, 5, 16.0, 304.0, 4.0],
#  [251,
#   'Consumer',
#   'OFF-PA-10004569',
#   10,
#   10,
#   1,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [252, 'Consumer', 'TEC-AC-10003832', 3050, 3350, 13, 4, 134.0, 3216.0, 166.0],
#  [253, 'Consumer', 'OFF-ST-10001228', 70, 80, 6, 5, 4.0, 76.0, 6.0],
#  [254,
#   'Consumer',
#   'OFF-EN-10003296',
#   330,
#   360,
#   4,
#   4,
#   14.4,
#   345.6,
#   15.600000000000023],
#  [255,
#   'Corporate',
#   'FUR-FU-10002505',
#   10,
#   10,
#   9,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [256,
#   'Corporate',
#   'OFF-ST-10004804',
#   70,
#   80,
#   2,
#   2,
#   1.6,
#   78.4,
#   8.400000000000006],
#  [257, 'Corporate', 'OFF-ST-10001590', 40, 50, 5, 2, 1.0, 49.0, 9.0],
#  [258, 'Corporate', 'TEC-PH-10001580', 590, 650, 6, 4, 26.0, 624.0, 34.0],
#  [259, 'Consumer', 'TEC-AC-10000290', 20, 20, 3, 5, 1.0, 19.0, -1.0],
#  [260,
#   'Consumer',
#   'OFF-ST-10002790',
#   180,
#   220,
#   3,
#   4,
#   8.8,
#   211.2,
#   31.19999999999999],
#  [261, 'Consumer', 'OFF-BI-10003460', 20, 20, 5, 5, 1.0, 19.0, -1.0],
#  [262, 'Corporate', 'OFF-AP-10002203', 0, 0, 2, 2, 0.0, 0.0, 0.0],
#  [263,
#   'Corporate',
#   'TEC-MA-10000822',
#   2690,
#   3060,
#   3,
#   3,
#   91.8,
#   2968.2,
#   278.1999999999998],
#  [264,
#   'Corporate',
#   'TEC-MA-10003353',
#   2170,
#   2520,
#   7,
#   3,
#   75.60000000000001,
#   2444.4,
#   274.4000000000001],
#  [265,
#   'Consumer',
#   'TEC-PH-10001433',
#   300,
#   330,
#   4,
#   3,
#   9.9,
#   320.1,
#   20.100000000000023],
#  [266,
#   'Consumer',
#   'TEC-AC-10004469',
#   70,
#   80,
#   2,
#   4,
#   3.2,
#   76.8,
#   6.799999999999997],
#  [267, 'Corporate', 'OFF-AR-10003602', 10, 10, 3, 5, 0.5, 9.5, -0.5],
#  [268,
#   'Consumer',
#   'OFF-FA-10003472',
#   10,
#   10,
#   6,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [269,
#   'Corporate',
#   'OFF-ST-10004180',
#   30,
#   40,
#   1,
#   3,
#   1.2,
#   38.8,
#   8.799999999999997],
#  [270,
#   'Corporate',
#   'OFF-EN-10004386',
#   50,
#   60,
#   3,
#   3,
#   1.8,
#   58.2,
#   8.200000000000003],
#  [271,
#   'Corporate',
#   'OFF-ST-10003208',
#   590,
#   730,
#   4,
#   2,
#   14.6,
#   715.4,
#   125.39999999999998],
#  [272, 'Consumer', 'TEC-AC-10003628', 200, 210, 7, 5, 10.5, 199.5, -0.5],
#  [273,
#   'Consumer',
#   'FUR-FU-10003274',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [274,
#   'Consumer',
#   'OFF-BI-10002557',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [275,
#   'Corporate',
#   'OFF-PA-10002615',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [276,
#   'Corporate',
#   'OFF-AR-10001427',
#   10,
#   10,
#   1,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [277,
#   'Corporate',
#   'OFF-PA-10000673',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [278,
#   'Corporate',
#   'OFF-PA-10004470',
#   20,
#   20,
#   4,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [279,
#   'Corporate',
#   'OFF-ST-10000876',
#   50,
#   60,
#   6,
#   2,
#   1.2,
#   58.8,
#   8.799999999999997],
#  [280, 'Corporate', 'OFF-LA-10002043', 20, 20, 3, 5, 1.0, 19.0, -1.0],
#  [281, 'Consumer', 'OFF-BI-10004967', 0, 0, 5, 3, 0.0, 0.0, 0.0],
#  [282,
#   'Consumer',
#   'TEC-PH-10001760',
#   1050,
#   1110,
#   7,
#   3,
#   33.3,
#   1076.7,
#   26.700000000000045],
#  [283, 'Consumer', 'FUR-TA-10002903', 950, 1040, 5, 5, 52.0, 988.0, 38.0],
#  [284, 'Consumer', 'OFF-PA-10000474', 130, 140, 5, 5, 7.0, 133.0, 3.0],
#  [285, 'Consumer', 'TEC-AC-10001956', 210, 240, 5, 5, 12.0, 228.0, 18.0],
#  [286, 'Consumer', 'OFF-PA-10004100', 30, 30, 6, 5, 1.5, 28.5, -1.5],
#  [287, 'Corporate', 'OFF-BI-10000778', 230, 250, 7, 3, 7.5, 242.5, 12.5],
#  [288,
#   'Corporate',
#   'OFF-AP-10002684',
#   150,
#   190,
#   2,
#   2,
#   3.8000000000000003,
#   186.2,
#   36.19999999999999],
#  [289, 'Corporate', 'OFF-SU-10000646', 810, 960, 5, 5, 48.0, 912.0, 102.0],
#  [290, 'Home Office', 'OFF-FA-10002983', 20, 20, 7, 5, 1.0, 19.0, -1.0],
#  [291,
#   'Home Office',
#   'OFF-LA-10004689',
#   20,
#   20,
#   8,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [292,
#   'Home Office',
#   'TEC-AC-10002001',
#   220,
#   260,
#   2,
#   2,
#   5.2,
#   254.8,
#   34.80000000000001],
#  [293,
#   'Home Office',
#   'FUR-BO-10004709',
#   80,
#   90,
#   3,
#   4,
#   3.6,
#   86.4,
#   6.400000000000006],
#  [294, 'Corporate', 'FUR-FU-10004091', 280, 300, 8, 5, 15.0, 285.0, 5.0],
#  [295,
#   'Corporate',
#   'FUR-CH-10001891',
#   190,
#   230,
#   3,
#   2,
#   4.6000000000000005,
#   225.4,
#   35.400000000000006],
#  [296,
#   'Corporate',
#   'FUR-FU-10002918',
#   180,
#   220,
#   3,
#   2,
#   4.4,
#   215.6,
#   35.599999999999994],
#  [297, 'Corporate', 'OFF-BI-10004593', 70, 80, 5, 5, 4.0, 76.0, 6.0],
#  [298,
#   'Corporate',
#   'OFF-FA-10004854',
#   30,
#   30,
#   3,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [299,
#   'Corporate',
#   'OFF-PA-10002105',
#   20,
#   30,
#   5,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [300,
#   'Corporate',
#   'OFF-ST-10002756',
#   930,
#   1080,
#   8,
#   2,
#   21.6,
#   1058.4,
#   128.4000000000001],
#  [301, 'Corporate', 'OFF-PA-10004243', 50, 60, 3, 5, 3.0, 57.0, 7.0],
#  [302,
#   'Corporate',
#   'FUR-FU-10001861',
#   70,
#   80,
#   4,
#   4,
#   3.2,
#   76.8,
#   6.799999999999997],
#  [303,
#   'Corporate',
#   'OFF-BI-10002706',
#   10,
#   10,
#   1,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [304,
#   'Consumer',
#   'FUR-TA-10002533',
#   180,
#   220,
#   3,
#   4,
#   8.8,
#   211.2,
#   31.19999999999999],
#  [305,
#   'Corporate',
#   'FUR-FU-10002671',
#   20,
#   30,
#   2,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [306,
#   'Corporate',
#   'OFF-AR-10003651',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [307, 'Home Office', 'OFF-BI-10001072', 50, 50, 3, 5, 2.5, 47.5, -2.5],
#  [308,
#   'Home Office',
#   'OFF-AR-10002135',
#   250,
#   290,
#   6,
#   4,
#   11.6,
#   278.4,
#   28.399999999999977],
#  [309, 'Consumer', 'OFF-AR-10002804', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [310, 'Corporate', 'FUR-FU-10001918', 20, 20, 4, 5, 1.0, 19.0, -1.0],
#  [311,
#   'Corporate',
#   'FUR-CH-10004086',
#   400,
#   470,
#   2,
#   4,
#   18.8,
#   451.2,
#   51.19999999999999],
#  [312,
#   'Corporate',
#   'FUR-FU-10001756',
#   20,
#   20,
#   1,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [313,
#   'Corporate',
#   'OFF-LA-10000634',
#   10,
#   10,
#   3,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [314,
#   'Corporate',
#   'FUR-FU-10001588',
#   80,
#   90,
#   3,
#   2,
#   1.8,
#   88.2,
#   8.200000000000003],
#  [315, 'Corporate', 'TEC-PH-10002398', 160, 180, 2, 5, 9.0, 171.0, 11.0],
#  [316, 'Corporate', 'OFF-PA-10001937', 20, 20, 3, 5, 1.0, 19.0, -1.0],
#  [317, 'Corporate', 'OFF-AR-10003373', 90, 100, 4, 2, 2.0, 98.0, 8.0],
#  [318,
#   'Home Office',
#   'FUR-CH-10002602',
#   120,
#   140,
#   1,
#   2,
#   2.8000000000000003,
#   137.2,
#   17.19999999999999],
#  [319,
#   'Home Office',
#   'TEC-MA-10002927',
#   3670,
#   3990,
#   2,
#   2,
#   79.8,
#   3910.2,
#   240.19999999999982],
#  [320,
#   'Home Office',
#   'TEC-PH-10004093',
#   230,
#   280,
#   6,
#   3,
#   8.4,
#   271.6,
#   41.60000000000002],
#  [321,
#   'Home Office',
#   'TEC-AC-10000892',
#   300,
#   360,
#   4,
#   3,
#   10.8,
#   349.2,
#   49.19999999999999],
#  [322,
#   'Home Office',
#   'OFF-ST-10002974',
#   40,
#   40,
#   1,
#   2,
#   0.8,
#   39.2,
#   -0.7999999999999972],
#  [323, 'Corporate', 'OFF-FA-10000624', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [324, 'Corporate', 'OFF-BI-10004593', 220, 250, 6, 5, 12.5, 237.5, 17.5],
#  [325, 'Corporate', 'TEC-AC-10001908', 80, 100, 1, 3, 3.0, 97.0, 17.0],
#  [326,
#   'Corporate',
#   'FUR-FU-10001967',
#   20,
#   20,
#   1,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [327,
#   'Consumer',
#   'TEC-PH-10003645',
#   270,
#   290,
#   3,
#   3,
#   8.700000000000001,
#   281.3,
#   11.300000000000011],
#  [328, 'Consumer', 'OFF-ST-10000675', 40, 50, 2, 5, 2.5, 47.5, 7.5],
#  [329,
#   'Consumer',
#   'FUR-CH-10003312',
#   740,
#   790,
#   4,
#   3,
#   23.7,
#   766.3,
#   26.299999999999955],
#  [330, 'Consumer', 'OFF-LA-10001074', 90, 100, 10, 2, 2.0, 98.0, 8.0],
#  [331,
#   'Consumer',
#   'OFF-BI-10001524',
#   30,
#   40,
#   6,
#   3,
#   1.2,
#   38.8,
#   8.799999999999997],
#  [332,
#   'Consumer',
#   'TEC-PH-10004614',
#   70,
#   80,
#   2,
#   3,
#   2.4,
#   77.6,
#   7.599999999999994],
#  [333,
#   'Consumer',
#   'OFF-BI-10001153',
#   20,
#   20,
#   2,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [334, 'Consumer', 'OFF-BI-10001982', 0, 0, 3, 3, 0.0, 0.0, 0.0],
#  [335, 'Consumer', 'OFF-BI-10001922', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [336,
#   'Consumer',
#   'TEC-CO-10001449',
#   770,
#   960,
#   2,
#   2,
#   19.2,
#   940.8,
#   170.79999999999995],
#  [337,
#   'Consumer',
#   'OFF-BI-10004140',
#   10,
#   10,
#   4,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [338, 'Corporate', 'OFF-BI-10003314', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [339, 'Corporate', 'FUR-TA-10004575', 570, 700, 3, 4, 28.0, 672.0, 102.0],
#  [340, 'Consumer', 'OFF-FA-10000490', 0, 0, 4, 2, 0.0, 0.0, 0.0],
#  [341,
#   'Corporate',
#   'OFF-AR-10000122',
#   20,
#   20,
#   4,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [342,
#   'Corporate',
#   'OFF-BI-10003656',
#   450,
#   510,
#   10,
#   4,
#   20.400000000000002,
#   489.6,
#   39.60000000000002],
#  [343, 'Corporate', 'OFF-FA-10002780', 20, 30, 13, 4, 1.2, 28.8, 8.8],
#  [344,
#   'Corporate',
#   'TEC-PH-10000702',
#   60,
#   70,
#   12,
#   4,
#   2.8000000000000003,
#   67.2,
#   7.200000000000003],
#  [345,
#   'Consumer',
#   'OFF-ST-10000107',
#   80,
#   90,
#   4,
#   3,
#   2.7,
#   87.3,
#   7.299999999999997],
#  [346, 'Consumer', 'TEC-PH-10002293', 50, 50, 3, 2, 1.0, 49.0, -1.0],
#  [347,
#   'Consumer',
#   'OFF-AR-10004027',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [348, 'Consumer', 'OFF-PA-10000249', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [349,
#   'Consumer',
#   'OFF-AR-10001374',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [350, 'Home Office', 'TEC-AC-10000290', 10, 10, 1, 5, 0.5, 9.5, -0.5],
#  [351, 'Home Office', 'OFF-PA-10001970', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [352, 'Home Office', 'OFF-BI-10002160', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [353, 'Home Office', 'OFF-PA-10001970', 50, 50, 4, 3, 1.5, 48.5, -1.5],
#  [354,
#   'Home Office',
#   'OFF-BI-10004995',
#   4140,
#   4360,
#   4,
#   4,
#   174.4,
#   4185.6,
#   45.600000000000364],
#  [355, 'Consumer', 'FUR-BO-10002268', 350, 390, 6, 5, 19.5, 370.5, 20.5],
#  [356, 'Consumer', 'OFF-EN-10001137', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [357,
#   'Consumer',
#   'OFF-AR-10002399',
#   20,
#   20,
#   4,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [358,
#   'Consumer',
#   'OFF-PA-10002713',
#   30,
#   30,
#   5,
#   2,
#   0.6,
#   29.4,
#   -0.6000000000000014],
#  [359,
#   'Corporate',
#   'OFF-PA-10002666',
#   30,
#   40,
#   5,
#   4,
#   1.6,
#   38.4,
#   8.399999999999999],
#  [360, 'Corporate', 'OFF-AP-10001124', 600, 650, 8, 3, 19.5, 630.5, 30.5],
#  [361,
#   'Corporate',
#   'OFF-LA-10001158',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [362,
#   'Consumer',
#   'OFF-LA-10001158',
#   20,
#   20,
#   2,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [363,
#   'Consumer',
#   'FUR-CH-10000785',
#   460,
#   490,
#   3,
#   4,
#   19.6,
#   470.4,
#   10.399999999999977],
#  [364,
#   'Consumer',
#   'OFF-AR-10003732',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [365, 'Consumer', 'FUR-FU-10000023', 40, 50, 8, 4, 2.0, 48.0, 8.0],
#  [366, 'Consumer', 'OFF-ST-10001713', 200, 210, 4, 5, 10.5, 199.5, -0.5],
#  [367,
#   'Corporate',
#   'OFF-BI-10002412',
#   20,
#   20,
#   4,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [368,
#   'Corporate',
#   'OFF-SU-10001225',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [369, 'Corporate', 'OFF-ST-10002406', 90, 100, 7, 3, 3.0, 97.0, 7.0],
#  [370, 'Corporate', 'FUR-BO-10002545', 900, 1040, 4, 5, 52.0, 988.0, 88.0],
#  [371, 'Consumer', 'OFF-PA-10002036', 30, 30, 5, 5, 1.5, 28.5, -1.5],
#  [372, 'Consumer', 'OFF-ST-10002205', 40, 50, 3, 3, 1.5, 48.5, 8.5],
#  [373,
#   'Consumer',
#   'OFF-BI-10001982',
#   10,
#   10,
#   5,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [374,
#   'Consumer',
#   'TEC-AC-10003911',
#   870,
#   1020,
#   8,
#   2,
#   20.400000000000002,
#   999.6,
#   129.60000000000002],
#  [375,
#   'Consumer',
#   'OFF-AR-10000658',
#   10,
#   10,
#   1,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [376,
#   'Consumer',
#   'TEC-AC-10002076',
#   410,
#   480,
#   10,
#   4,
#   19.2,
#   460.8,
#   50.80000000000001],
#  [377, 'Corporate', 'OFF-PA-10003039', 80, 100, 4, 3, 3.0, 97.0, 17.0],
#  [378,
#   'Corporate',
#   'FUR-TA-10004915',
#   1300,
#   1490,
#   7,
#   2,
#   29.8,
#   1460.2,
#   160.20000000000005],
#  [379, 'Consumer', 'OFF-AP-10000696', 10, 10, 3, 5, 0.5, 9.5, -0.5],
#  [380,
#   'Consumer',
#   'OFF-ST-10003327',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [381,
#   'Consumer',
#   'OFF-BI-10000309',
#   10,
#   10,
#   4,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [382, 'Corporate', 'OFF-PA-10004734', 40, 50, 7, 5, 2.5, 47.5, 7.5],
#  [383, 'Corporate', 'OFF-BI-10002225', 50, 50, 3, 5, 2.5, 47.5, -2.5],
#  [384,
#   'Corporate',
#   'TEC-AC-10004708',
#   40,
#   40,
#   2,
#   2,
#   0.8,
#   39.2,
#   -0.7999999999999972],
#  [385,
#   'Consumer',
#   'FUR-TA-10000617',
#   330,
#   380,
#   3,
#   4,
#   15.200000000000001,
#   364.8,
#   34.80000000000001],
#  [386,
#   'Consumer',
#   'TEC-AC-10002335',
#   70,
#   80,
#   3,
#   3,
#   2.4,
#   77.6,
#   7.599999999999994],
#  [387,
#   'Corporate',
#   'TEC-MA-10001681',
#   400,
#   480,
#   4,
#   2,
#   9.6,
#   470.4,
#   70.39999999999998],
#  [388, 'Corporate', 'FUR-FU-10001935', 0, 0, 1, 5, 0.0, 0.0, 0.0],
#  [389, 'Consumer', 'OFF-AR-10004757', 0, 0, 1, 2, 0.0, 0.0, 0.0],
#  [390,
#   'Consumer',
#   'OFF-BI-10000050',
#   20,
#   20,
#   4,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [391, 'Consumer', 'TEC-AC-10001998', 40, 40, 2, 5, 2.0, 38.0, -2.0],
#  [392, 'Consumer', 'TEC-PH-10003012', 230, 250, 2, 4, 10.0, 240.0, 10.0],
#  [393, 'Consumer', 'TEC-CO-10002313', 1600, 1800, 3, 2, 36.0, 1764.0, 164.0],
#  [394,
#   'Corporate',
#   'OFF-BI-10003982',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [395,
#   'Home Office',
#   'OFF-BI-10004492',
#   60,
#   80,
#   3,
#   3,
#   2.4,
#   77.6,
#   17.599999999999994],
#  [396, 'Corporate', 'OFF-ST-10000798', 40, 50, 2, 3, 1.5, 48.5, 8.5],
#  [397,
#   'Corporate',
#   'OFF-PA-10002552',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [398, 'Home Office', 'OFF-SU-10002573', 60, 70, 4, 5, 3.5, 66.5, 6.5],
#  [399,
#   'Consumer',
#   'OFF-ST-10001580',
#   40,
#   40,
#   3,
#   3,
#   1.2,
#   38.8,
#   -1.2000000000000028],
#  [400, 'Consumer', 'FUR-BO-10004834', 1990, 2400, 4, 5, 120.0, 2280.0, 290.0],
#  [401, 'Consumer', 'OFF-ST-10000934', 110, 130, 4, 5, 6.5, 123.5, 13.5],
#  [402,
#   'Consumer',
#   'TEC-AC-10000158',
#   60,
#   60,
#   2,
#   3,
#   1.8,
#   58.2,
#   -1.7999999999999972],
#  [403,
#   'Consumer',
#   'OFF-PA-10001947',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [404,
#   'Corporate',
#   'OFF-AR-10003478',
#   30,
#   40,
#   6,
#   4,
#   1.6,
#   38.4,
#   8.399999999999999],
#  [405,
#   'Consumer',
#   'OFF-AP-10004249',
#   40,
#   40,
#   3,
#   3,
#   1.2,
#   38.8,
#   -1.2000000000000028],
#  [406,
#   'Consumer',
#   'TEC-AC-10000158',
#   140,
#   180,
#   5,
#   4,
#   7.2,
#   172.8,
#   32.80000000000001],
#  [407, 'Consumer', 'TEC-CO-10004115', 1130, 1200, 3, 5, 60.0, 1140.0, 10.0],
#  [408,
#   'Consumer',
#   'OFF-PA-10003724',
#   30,
#   30,
#   5,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [409, 'Consumer', 'FUR-TA-10002041', 800, 1000, 7, 4, 40.0, 960.0, 160.0],
#  [410,
#   'Consumer',
#   'OFF-PA-10002893',
#   10,
#   10,
#   1,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [411,
#   'Consumer',
#   'OFF-LA-10003766',
#   30,
#   30,
#   9,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [412, 'Consumer', 'OFF-PA-10001970', 60, 60, 1, 5, 3.0, 57.0, -3.0],
#  [413,
#   'Consumer',
#   'FUR-BO-10001972',
#   1260,
#   1340,
#   13,
#   4,
#   53.6,
#   1286.4,
#   26.40000000000009],
#  [414, 'Consumer', 'FUR-CH-10003956', 100, 110, 2, 5, 5.5, 104.5, 4.5],
#  [415,
#   'Corporate',
#   'OFF-PA-10000157',
#   120,
#   140,
#   7,
#   3,
#   4.2,
#   135.8,
#   15.800000000000011],
#  [416,
#   'Corporate',
#   'FUR-CH-10001891',
#   250,
#   310,
#   4,
#   2,
#   6.2,
#   303.8,
#   53.80000000000001],
#  [417, 'Consumer', 'OFF-AR-10004344', 90, 100, 8, 5, 5.0, 95.0, 5.0],
#  [418,
#   'Consumer',
#   'FUR-CH-10004886',
#   320,
#   380,
#   5,
#   4,
#   15.200000000000001,
#   364.8,
#   44.80000000000001],
#  [419, 'Corporate', 'OFF-PA-10003845', 10, 10, 1, 5, 0.5, 9.5, -0.5],
#  [420,
#   'Corporate',
#   'OFF-AR-10001573',
#   10,
#   10,
#   4,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [421, 'Corporate', 'OFF-EN-10000483', 20, 20, 1, 5, 1.0, 19.0, -1.0],
#  [422, 'Consumer', 'TEC-AC-10004114', 160, 200, 6, 3, 6.0, 194.0, 34.0],
#  [423,
#   'Corporate',
#   'FUR-FU-10004712',
#   60,
#   60,
#   4,
#   3,
#   1.8,
#   58.2,
#   -1.7999999999999972],
#  [424, 'Corporate', 'OFF-ST-10000918', 30, 30, 3, 5, 1.5, 28.5, -1.5],
#  [425,
#   'Consumer',
#   'FUR-CH-10000015',
#   800,
#   870,
#   4,
#   4,
#   34.800000000000004,
#   835.2,
#   35.200000000000045],
#  [426,
#   'Corporate',
#   'FUR-FU-10003347',
#   30,
#   30,
#   2,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [427,
#   'Corporate',
#   'OFF-BI-10001543',
#   280,
#   290,
#   8,
#   4,
#   11.6,
#   278.4,
#   -1.6000000000000227],
#  [428,
#   'Home Office',
#   'TEC-MA-10000029',
#   60,
#   70,
#   1,
#   3,
#   2.1,
#   67.9,
#   7.900000000000006],
#  [429, 'Corporate', 'OFF-AR-10000369', 10, 10, 6, 5, 0.5, 9.5, -0.5],
#  [430,
#   'Home Office',
#   'OFF-BI-10004584',
#   160,
#   190,
#   2,
#   4,
#   7.6000000000000005,
#   182.4,
#   22.400000000000006],
#  [431,
#   'Home Office',
#   'TEC-AC-10004659',
#   330,
#   410,
#   7,
#   3,
#   12.3,
#   397.7,
#   67.69999999999999],
#  [432, 'Home Office', 'TEC-AC-10004659', 270, 290, 5, 5, 14.5, 275.5, 5.5],
#  [433, 'Home Office', 'OFF-ST-10000617', 0, 0, 2, 3, 0.0, 0.0, 0.0],
#  [434,
#   'Consumer',
#   'OFF-ST-10003306',
#   580,
#   710,
#   5,
#   4,
#   28.400000000000002,
#   681.6,
#   101.60000000000002],
#  [435, 'Consumer', 'OFF-BI-10000773', 0, 0, 2, 5, 0.0, 0.0, 0.0],
#  [436, 'Consumer', 'TEC-AC-10002600', 210, 250, 5, 2, 5.0, 245.0, 35.0],
#  [437,
#   'Home Office',
#   'TEC-MA-10002937',
#   930,
#   1010,
#   3,
#   4,
#   40.4,
#   969.6,
#   39.60000000000002],
#  [438,
#   'Home Office',
#   'OFF-PA-10001970',
#   270,
#   310,
#   7,
#   4,
#   12.4,
#   297.6,
#   27.600000000000023],
#  [439,
#   'Corporate',
#   'OFF-PA-10002230',
#   30,
#   30,
#   8,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [440, 'Corporate', 'FUR-CH-10003396', 190, 210, 3, 5, 10.5, 199.5, 9.5],
#  [441,
#   'Consumer',
#   'FUR-FU-10000246',
#   10,
#   10,
#   1,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [442,
#   'Consumer',
#   'OFF-ST-10000060',
#   150,
#   190,
#   3,
#   4,
#   7.6000000000000005,
#   182.4,
#   32.400000000000006],
#  [443,
#   'Consumer',
#   'OFF-ST-10003058',
#   60,
#   70,
#   3,
#   4,
#   2.8000000000000003,
#   67.2,
#   7.200000000000003],
#  [444,
#   'Consumer',
#   'OFF-PA-10002222',
#   80,
#   90,
#   4,
#   3,
#   2.7,
#   87.3,
#   7.299999999999997],
#  [445,
#   'Consumer',
#   'FUR-CH-10002372',
#   210,
#   240,
#   3,
#   4,
#   9.6,
#   230.4,
#   20.400000000000006],
#  [446,
#   'Consumer',
#   'OFF-LA-10001317',
#   20,
#   20,
#   7,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [447, 'Consumer', 'FUR-FU-10000206', 0, 0, 1, 2, 0.0, 0.0, 0.0],
#  [448,
#   'Consumer',
#   'OFF-AR-10000588',
#   50,
#   60,
#   3,
#   4,
#   2.4,
#   57.6,
#   7.600000000000001],
#  [449,
#   'Consumer',
#   'OFF-ST-10001469',
#   130,
#   160,
#   3,
#   4,
#   6.4,
#   153.6,
#   23.599999999999994],
#  [450,
#   'Consumer',
#   'OFF-AR-10001953',
#   210,
#   260,
#   6,
#   2,
#   5.2,
#   254.8,
#   44.80000000000001],
#  [451,
#   'Consumer',
#   'OFF-AR-10003156',
#   30,
#   30,
#   3,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [452,
#   'Consumer',
#   'OFF-AR-10004974',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [453,
#   'Consumer',
#   'TEC-PH-10002365',
#   40,
#   40,
#   4,
#   3,
#   1.2,
#   38.8,
#   -1.2000000000000028],
#  [454,
#   'Corporate',
#   'FUR-TA-10001539',
#   220,
#   280,
#   2,
#   4,
#   11.200000000000001,
#   268.8,
#   48.80000000000001],
#  [455,
#   'Corporate',
#   'OFF-ST-10000142',
#   570,
#   670,
#   2,
#   2,
#   13.4,
#   656.6,
#   86.60000000000002],
#  [456, 'Corporate', 'TEC-AC-10001772', 50, 60, 4, 5, 3.0, 57.0, 7.0],
#  [457,
#   'Consumer',
#   'FUR-CH-10000225',
#   120,
#   130,
#   2,
#   2,
#   2.6,
#   127.4,
#   7.400000000000006],
#  [458, 'Consumer', 'FUR-CH-10002331', 670, 750, 3, 5, 37.5, 712.5, 42.5],
#  [459,
#   'Consumer',
#   'OFF-EN-10001415',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [460, 'Consumer', 'OFF-AP-10002472', 80, 100, 4, 3, 3.0, 97.0, 17.0],
#  [461, 'Consumer', 'TEC-AC-10004571', 760, 900, 9, 5, 45.0, 855.0, 95.0],
#  [462, 'Consumer', 'OFF-BI-10001098', 50, 50, 3, 2, 1.0, 49.0, -1.0],
#  [463,
#   'Home Office',
#   'FUR-FU-10000023',
#   20,
#   20,
#   5,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [464,
#   'Home Office',
#   'FUR-TA-10001889',
#   1080,
#   1270,
#   6,
#   4,
#   50.800000000000004,
#   1219.2,
#   139.20000000000005],
#  [465,
#   'Home Office',
#   'OFF-BI-10000315',
#   30,
#   30,
#   5,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [466, 'Home Office', 'OFF-SU-10003505', 180, 190, 2, 5, 9.5, 180.5, 0.5],
#  [467,
#   'Home Office',
#   'OFF-AP-10002578',
#   80,
#   80,
#   2,
#   3,
#   2.4,
#   77.6,
#   -2.4000000000000057],
#  [468, 'Home Office', 'FUR-FU-10002918', 200, 250, 7, 3, 7.5, 242.5, 42.5],
#  [469, 'Corporate', 'FUR-BO-10002824', 200, 210, 2, 5, 10.5, 199.5, -0.5],
#  [470, 'Consumer', 'OFF-BI-10002194', 0, 0, 3, 3, 0.0, 0.0, 0.0],
#  [471,
#   'Corporate',
#   'OFF-PA-10004071',
#   50,
#   60,
#   1,
#   3,
#   1.8,
#   58.2,
#   8.200000000000003],
#  [472,
#   'Consumer',
#   'OFF-ST-10002743',
#   290,
#   340,
#   3,
#   2,
#   6.8,
#   333.2,
#   43.19999999999999],
#  [473, 'Consumer', 'FUR-BO-10001601', 200, 220, 2, 5, 11.0, 209.0, 9.0],
#  [474, 'Consumer', 'TEC-PH-10002680', 610, 700, 4, 2, 14.0, 686.0, 76.0],
#  [475,
#   'Consumer',
#   'OFF-ST-10001321',
#   80,
#   90,
#   6,
#   3,
#   2.7,
#   87.3,
#   7.299999999999997],
#  [476,
#   'Consumer',
#   'OFF-PA-10001509',
#   60,
#   60,
#   7,
#   3,
#   1.8,
#   58.2,
#   -1.7999999999999972],
#  [477,
#   'Consumer',
#   'OFF-PA-10003465',
#   90,
#   90,
#   5,
#   4,
#   3.6,
#   86.4,
#   -3.5999999999999943],
#  [478, 'Corporate', 'TEC-PH-10000149', 90, 100, 6, 4, 4.0, 96.0, 6.0],
#  [479,
#   'Consumer',
#   'FUR-FU-10002671',
#   30,
#   40,
#   3,
#   4,
#   1.6,
#   38.4,
#   8.399999999999999],
#  [480,
#   'Corporate',
#   'OFF-AR-10003045',
#   10,
#   10,
#   5,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [481, 'Corporate', 'OFF-ST-10000689', 600, 700, 5, 5, 35.0, 665.0, 65.0],
#  [482,
#   'Consumer',
#   'TEC-AC-10001445',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [483,
#   'Consumer',
#   'OFF-AR-10002053',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [484,
#   'Consumer',
#   'TEC-AC-10002567',
#   140,
#   160,
#   2,
#   4,
#   6.4,
#   153.6,
#   13.599999999999994],
#  [485, 'Home Office', 'OFF-LA-10003923', 30, 30, 2, 5, 1.5, 28.5, -1.5],
#  [486,
#   'Home Office',
#   'FUR-BO-10001337',
#   480,
#   510,
#   5,
#   4,
#   20.400000000000002,
#   489.6,
#   9.600000000000023],
#  [487, 'Home Office', 'TEC-PH-10001924', 250, 280, 5, 5, 14.0, 266.0, 16.0],
#  [488,
#   'Consumer',
#   'TEC-PH-10001363',
#   2300,
#   2740,
#   6,
#   4,
#   109.60000000000001,
#   2630.4,
#   330.4000000000001],
#  [489, 'Home Office', 'TEC-PH-10000376', 10, 10, 1, 5, 0.5, 9.5, -0.5],
#  [490, 'Home Office', 'TEC-AC-10000303', 50, 60, 2, 5, 3.0, 57.0, 7.0],
#  [491,
#   'Home Office',
#   'OFF-AR-10001953',
#   70,
#   70,
#   2,
#   4,
#   2.8000000000000003,
#   67.2,
#   -2.799999999999997],
#  [492, 'Consumer', 'OFF-ST-10001809', 410, 450, 5, 4, 18.0, 432.0, 22.0],
#  [493, 'Consumer', 'OFF-EN-10003845', 10, 10, 3, 5, 0.5, 9.5, -0.5],
#  [494,
#   'Consumer',
#   'TEC-AC-10000991',
#   80,
#   90,
#   2,
#   4,
#   3.6,
#   86.4,
#   6.400000000000006],
#  [495, 'Consumer', 'FUR-TA-10001857', 180, 190, 3, 5, 9.5, 180.5, 0.5],
#  [496,
#   'Consumer',
#   'OFF-EN-10001434',
#   100,
#   110,
#   2,
#   3,
#   3.3000000000000003,
#   106.7,
#   6.700000000000003],
#  [497,
#   'Consumer',
#   'OFF-BI-10002498',
#   110,
#   120,
#   8,
#   2,
#   2.4,
#   117.6,
#   7.599999999999994],
#  [498,
#   'Consumer',
#   'FUR-FU-10004864',
#   230,
#   260,
#   4,
#   2,
#   5.2,
#   254.8,
#   24.80000000000001],
#  [499, 'Consumer', 'FUR-CH-10002602', 200, 240, 2, 5, 12.0, 228.0, 28.0],
#  [500, 'Consumer', 'FUR-FU-10000073', 60, 70, 9, 5, 3.5, 66.5, 6.5],
#  [501,
#   'Corporate',
#   'OFF-BI-10001670',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [502, 'Corporate', 'OFF-BI-10001658', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [503, 'Corporate', 'FUR-CH-10001215', 650, 800, 2, 3, 24.0, 776.0, 126.0],
#  [504, 'Corporate', 'OFF-BI-10000831', 0, 0, 3, 4, 0.0, 0.0, 0.0],
#  [505,
#   'Corporate',
#   'OFF-PA-10000357',
#   30,
#   30,
#   1,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [506,
#   'Corporate',
#   'OFF-BI-10003274',
#   20,
#   20,
#   5,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [507, 'Consumer', 'OFF-AR-10001662', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [508,
#   'Consumer',
#   'OFF-AR-10003856',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [509, 'Consumer', 'OFF-ST-10001228', 50, 50, 3, 4, 2.0, 48.0, -2.0],
#  [510, 'Consumer', 'OFF-BI-10003527', 5210, 6350, 5, 3, 190.5, 6159.5, 949.5],
#  [511,
#   'Consumer',
#   'FUR-FU-10001290',
#   110,
#   130,
#   3,
#   2,
#   2.6,
#   127.4,
#   17.400000000000006],
#  [512,
#   'Consumer',
#   'TEC-AC-10002399',
#   40,
#   40,
#   2,
#   2,
#   0.8,
#   39.2,
#   -0.7999999999999972],
#  [513,
#   'Consumer',
#   'OFF-AR-10002053',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [514,
#   'Consumer',
#   'OFF-AR-10003811',
#   10,
#   10,
#   3,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [515,
#   'Consumer',
#   'OFF-AR-10001246',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [516,
#   'Home Office',
#   'TEC-CO-10003236',
#   2430,
#   3000,
#   5,
#   5,
#   150.0,
#   2850.0,
#   420.0],
#  [517, 'Home Office', 'OFF-ST-10004507', 40, 50, 3, 4, 2.0, 48.0, 8.0],
#  [518,
#   'Home Office',
#   'OFF-PA-10001667',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [519, 'Home Office', 'OFF-ST-10004459', 1020, 1130, 3, 5, 56.5, 1073.5, 53.5],
#  [520,
#   'Consumer',
#   'TEC-AC-10000171',
#   20,
#   20,
#   1,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [521,
#   'Consumer',
#   'OFF-ST-10000736',
# ...
#  [829,
#   'Consumer',
#   'OFF-EN-10004459',
#   20,
#   20,
#   2,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [830, 'Consumer', 'FUR-CH-10000665', 250, 300, 2, 4, 12.0, 288.0, 38.0],
#  [831,
#   'Consumer',
#   'OFF-AP-10003884',
#   150,
#   180,
#   3,
#   4,
#   7.2,
#   172.8,
#   22.80000000000001],
#  [832,
#   'Consumer',
#   'TEC-PH-10001557',
#   180,
#   190,
#   2,
#   4,
#   7.6000000000000005,
#   182.4,
#   2.4000000000000057],
#  [833, 'Consumer', 'TEC-PH-10002085', 60, 70, 1, 5, 3.5, 66.5, 6.5],
#  [834,
#   'Corporate',
#   'OFF-AR-10002956',
#   30,
#   40,
#   2,
#   2,
#   0.8,
#   39.2,
#   9.200000000000003],
#  [835,
#   'Corporate',
#   'OFF-AP-10003266',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [836,
#   'Corporate',
#   'TEC-MA-10004002',
#   220,
#   270,
#   1,
#   3,
#   8.1,
#   261.9,
#   41.89999999999998],
#  [837, 'Consumer', 'OFF-BI-10001071', 40, 50, 4, 2, 1.0, 49.0, 9.0],
#  [838,
#   'Home Office',
#   'OFF-PA-10001560',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [839,
#   'Corporate',
#   'TEC-PH-10002365',
#   20,
#   20,
#   3,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [840,
#   'Corporate',
#   'OFF-AR-10004648',
#   50,
#   60,
#   3,
#   3,
#   1.8,
#   58.2,
#   8.200000000000003],
#  [841, 'Corporate', 'OFF-AR-10002578', 10, 10, 4, 5, 0.5, 9.5, -0.5],
#  [842,
#   'Corporate',
#   'FUR-BO-10001519',
#   170,
#   190,
#   4,
#   2,
#   3.8000000000000003,
#   186.2,
#   16.19999999999999],
#  [843, 'Corporate', 'OFF-BI-10001294', 30, 40, 4, 5, 2.0, 38.0, 8.0],
#  [844,
#   'Corporate',
#   'OFF-BI-10001636',
#   30,
#   30,
#   4,
#   2,
#   0.6,
#   29.4,
#   -0.6000000000000014],
#  [845, 'Corporate', 'OFF-SU-10002503', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [846, 'Corporate', 'OFF-LA-10004093', 10, 10, 2, 5, 0.5, 9.5, -0.5],
#  [847,
#   'Consumer',
#   'TEC-PH-10001552',
#   70,
#   80,
#   7,
#   3,
#   2.4,
#   77.6,
#   7.599999999999994],
#  [848,
#   'Consumer',
#   'FUR-CH-10001891',
#   230,
#   290,
#   3,
#   3,
#   8.700000000000001,
#   281.3,
#   51.30000000000001],
#  [849, 'Consumer', 'FUR-FU-10003878', 40, 50, 4, 2, 1.0, 49.0, 9.0],
#  [850,
#   'Corporate',
#   'TEC-AC-10000710',
#   110,
#   120,
#   7,
#   3,
#   3.6,
#   116.4,
#   6.400000000000006],
#  [851,
#   'Corporate',
#   'OFF-AR-10002335',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [852, 'Corporate', 'OFF-PA-10001870', 30, 40, 6, 5, 2.0, 38.0, 8.0],
#  [853,
#   'Consumer',
#   'OFF-AR-10003373',
#   160,
#   190,
#   6,
#   2,
#   3.8000000000000003,
#   186.2,
#   26.19999999999999],
#  [854,
#   'Consumer',
#   'FUR-FU-10004090',
#   30,
#   40,
#   2,
#   4,
#   1.6,
#   38.4,
#   8.399999999999999],
#  [855,
#   'Consumer',
#   'OFF-ST-10000736',
#   190,
#   240,
#   3,
#   2,
#   4.8,
#   235.2,
#   45.19999999999999],
#  [856, 'Consumer', 'OFF-PA-10001019', 30, 40, 2, 5, 2.0, 38.0, 8.0],
#  [857, 'Consumer', 'OFF-SU-10002537', 90, 100, 10, 2, 2.0, 98.0, 8.0],
#  [858,
#   'Consumer',
#   'OFF-ST-10003221',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [859,
#   'Home Office',
#   'OFF-PA-10004569',
#   10,
#   10,
#   1,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [860,
#   'Home Office',
#   'OFF-FA-10000624',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [861,
#   'Consumer',
#   'OFF-SU-10001225',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [862,
#   'Consumer',
#   'OFF-AR-10003752',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [863,
#   'Corporate',
#   'TEC-AC-10001714',
#   170,
#   190,
#   6,
#   2,
#   3.8000000000000003,
#   186.2,
#   16.19999999999999],
#  [864,
#   'Corporate',
#   'OFF-AR-10003958',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [865,
#   'Corporate',
#   'TEC-PH-10002923',
#   50,
#   60,
#   2,
#   2,
#   1.2,
#   58.8,
#   8.799999999999997],
#  [866, 'Corporate', 'OFF-LA-10004272', 0, 0, 1, 4, 0.0, 0.0, 0.0],
#  [867, 'Corporate', 'FUR-FU-10000965', 40, 50, 1, 4, 2.0, 48.0, 8.0],
#  [868, 'Corporate', 'OFF-LA-10004853', 20, 20, 4, 5, 1.0, 19.0, -1.0],
#  [869,
#   'Corporate',
#   'OFF-BI-10003719',
#   30,
#   40,
#   6,
#   2,
#   0.8,
#   39.2,
#   9.200000000000003],
#  [870,
#   'Home Office',
#   'OFF-BI-10000545',
#   910,
#   1140,
#   5,
#   2,
#   22.8,
#   1117.2,
#   207.20000000000005],
#  [871, 'Home Office', 'TEC-PH-10002496', 260, 280, 3, 5, 14.0, 266.0, 6.0],
#  [872,
#   'Consumer',
#   'OFF-PA-10003591',
#   30,
#   30,
#   3,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [873,
#   'Consumer',
#   'OFF-PA-10004470',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [874, 'Consumer', 'OFF-BI-10000315', 100, 110, 7, 5, 5.5, 104.5, 4.5],
#  [875,
#   'Consumer',
#   'OFF-PA-10001790',
#   160,
#   190,
#   5,
#   4,
#   7.6000000000000005,
#   182.4,
#   22.400000000000006],
#  [876,
#   'Home Office',
#   'FUR-FU-10004017',
#   280,
#   320,
#   3,
#   2,
#   6.4,
#   313.6,
#   33.60000000000002],
#  [877,
#   'Home Office',
#   'TEC-AC-10003628',
#   30,
#   30,
#   1,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [878,
#   'Home Office',
#   'TEC-AC-10002049',
#   330,
#   370,
#   3,
#   4,
#   14.8,
#   355.2,
#   25.19999999999999],
#  [879,
#   'Home Office',
#   'OFF-BI-10003712',
#   10,
#   10,
#   4,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [880,
#   'Home Office',
#   'OFF-BI-10003984',
#   60,
#   70,
#   3,
#   3,
#   2.1,
#   67.9,
#   7.900000000000006],
#  [881,
#   'Home Office',
#   'FUR-CH-10004287',
#   1170,
#   1240,
#   5,
#   2,
#   24.8,
#   1215.2,
#   45.200000000000045],
#  [882,
#   'Consumer',
#   'OFF-ST-10001321',
#   30,
#   30,
#   2,
#   2,
#   0.6,
#   29.4,
#   -0.6000000000000014],
#  [883,
#   'Consumer',
#   'OFF-AR-10001118',
#   10,
#   10,
#   4,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [884,
#   'Home Office',
#   'FUR-FU-10000732',
#   20,
#   30,
#   5,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [885, 'Consumer', 'FUR-FU-10001424', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [886,
#   'Corporate',
#   'OFF-BI-10002071',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [887, 'Consumer', 'OFF-ST-10002486', 70, 80, 12, 5, 4.0, 76.0, 6.0],
#  [888, 'Home Office', 'OFF-BI-10001078', 30, 40, 7, 5, 2.0, 38.0, 8.0],
#  [889,
#   'Corporate',
#   'OFF-PA-10003845',
#   30,
#   30,
#   6,
#   2,
#   0.6,
#   29.4,
#   -0.6000000000000014],
#  [890, 'Consumer', 'TEC-AC-10000927', 130, 150, 5, 3, 4.5, 145.5, 15.5],
#  [891, 'Consumer', 'OFF-BI-10001098', 40, 50, 3, 4, 2.0, 48.0, 8.0],
#  [892, 'Home Office', 'OFF-PA-10001622', 0, 0, 1, 4, 0.0, 0.0, 0.0],
#  [893,
#   'Home Office',
#   'OFF-AR-10003158',
#   20,
#   20,
#   4,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [894,
#   'Home Office',
#   'TEC-PH-10002660',
#   510,
#   540,
#   8,
#   2,
#   10.8,
#   529.2,
#   19.200000000000045],
#  [895,
#   'Corporate',
#   'OFF-ST-10002205',
#   130,
#   160,
#   7,
#   3,
#   4.8,
#   155.2,
#   25.19999999999999],
#  [896,
#   'Corporate',
#   'OFF-BI-10003364',
#   60,
#   70,
#   3,
#   2,
#   1.4000000000000001,
#   68.6,
#   8.599999999999994],
#  [897,
#   'Consumer',
#   'OFF-EN-10001099',
#   20,
#   20,
#   2,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [898, 'Consumer', 'OFF-LA-10003923', 90, 100, 7, 2, 2.0, 98.0, 8.0],
#  [899, 'Corporate', 'OFF-PA-10002250', 50, 50, 8, 3, 1.5, 48.5, -1.5],
#  [900,
#   'Corporate',
#   'OFF-BI-10004716',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [901, 'Consumer', 'OFF-LA-10001045', 10, 10, 5, 5, 0.5, 9.5, -0.5],
#  [902,
#   'Consumer',
#   'OFF-BI-10001510',
#   20,
#   20,
#   4,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [903,
#   'Consumer',
#   'TEC-PH-10004536',
#   260,
#   320,
#   3,
#   2,
#   6.4,
#   313.6,
#   53.60000000000002],
#  [904,
#   'Consumer',
#   'OFF-PA-10002947',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [905,
#   'Consumer',
#   'OFF-ST-10002583',
#   50,
#   60,
#   2,
#   2,
#   1.2,
#   58.8,
#   8.799999999999997],
#  [906,
#   'Consumer',
#   'OFF-PA-10000019',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [907,
#   'Consumer',
#   'FUR-BO-10003441',
#   280,
#   320,
#   4,
#   4,
#   12.8,
#   307.2,
#   27.19999999999999],
#  [908,
#   'Consumer',
#   'TEC-PH-10004774',
#   70,
#   90,
#   7,
#   4,
#   3.6,
#   86.4,
#   16.400000000000006],
#  [909, 'Consumer', 'OFF-BI-10003684', 40, 50, 3, 3, 1.5, 48.5, 8.5],
#  [910,
#   'Home Office',
#   'TEC-PH-10001494',
#   1010,
#   1200,
#   4,
#   3,
#   36.0,
#   1164.0,
#   154.0],
#  [911,
#   'Home Office',
#   'TEC-AC-10004666',
#   1830,
#   1930,
#   7,
#   4,
#   77.2,
#   1852.8,
#   22.799999999999955],
#  [912, 'Home Office', 'OFF-ST-10003816', 320, 350, 2, 3, 10.5, 339.5, 19.5],
#  [913, 'Home Office', 'FUR-FU-10001935', 20, 20, 6, 5, 1.0, 19.0, -1.0],
#  [914, 'Corporate', 'FUR-FU-10004091', 40, 50, 1, 5, 2.5, 47.5, 7.5],
#  [915,
#   'Corporate',
#   'TEC-AC-10001772',
#   130,
#   140,
#   9,
#   4,
#   5.6000000000000005,
#   134.4,
#   4.400000000000006],
#  [916, 'Corporate', 'FUR-TA-10001520', 90, 100, 2, 4, 4.0, 96.0, 6.0],
#  [917, 'Corporate', 'FUR-CH-10003379', 680, 800, 4, 5, 40.0, 760.0, 80.0],
#  [918,
#   'Corporate',
#   'OFF-BI-10002706',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [919, 'Corporate', 'OFF-EN-10000056', 130, 150, 3, 4, 6.0, 144.0, 14.0],
#  [920, 'Corporate', 'OFF-ST-10001558', 10, 10, 1, 5, 0.5, 9.5, -0.5],
#  [921,
#   'Consumer',
#   'OFF-ST-10002444',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [922, 'Consumer', 'TEC-AC-10002473', 80, 90, 3, 5, 4.5, 85.5, 5.5],
#  [923,
#   'Consumer',
#   'TEC-PH-10004531',
#   20,
#   20,
#   1,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [924,
#   'Consumer',
#   'OFF-AP-10004487',
#   340,
#   410,
#   5,
#   4,
#   16.4,
#   393.6,
#   53.60000000000002],
#  [925,
#   'Corporate',
#   'OFF-BI-10003650',
#   720,
#   840,
#   2,
#   3,
#   25.2,
#   814.8,
#   94.79999999999995],
#  [926,
#   'Consumer',
#   'OFF-PA-10003543',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [927, 'Consumer', 'TEC-AC-10004353', 210, 250, 5, 3, 7.5, 242.5, 32.5],
#  [928, 'Home Office', 'OFF-AR-10000658', 40, 50, 4, 3, 1.5, 48.5, 8.5],
#  [929, 'Home Office', 'OFF-AP-10000696', 20, 30, 2, 5, 1.5, 28.5, 8.5],
#  [930,
#   'Consumer',
#   'OFF-AR-10003560',
#   10,
#   10,
#   3,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [931,
#   'Consumer',
#   'OFF-AR-10001468',
#   90,
#   90,
#   3,
#   2,
#   1.8,
#   88.2,
#   -1.7999999999999972],
#  [932,
#   'Consumer',
#   'OFF-PA-10004971',
#   10,
#   10,
#   3,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [933,
#   'Consumer',
#   'OFF-PA-10002195',
#   10,
#   10,
#   3,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [934, 'Home Office', 'OFF-PA-10001745', 40, 50, 8, 4, 2.0, 48.0, 8.0],
#  [935,
#   'Home Office',
#   'OFF-BI-10004826',
#   20,
#   30,
#   6,
#   3,
#   0.9,
#   29.1,
#   9.100000000000001],
#  [936,
#   'Home Office',
#   'OFF-PA-10001870',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [937, 'Home Office', 'OFF-AP-10001058', 410, 450, 2, 3, 13.5, 436.5, 26.5],
#  [938,
#   'Corporate',
#   'TEC-AC-10003911',
#   140,
#   160,
#   1,
#   3,
#   4.8,
#   155.2,
#   15.199999999999989],
#  [939,
#   'Corporate',
#   'OFF-PA-10000289',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [940,
#   'Corporate',
#   'OFF-AP-10003040',
#   120,
#   130,
#   4,
#   3,
#   3.9,
#   126.1,
#   6.099999999999994],
#  [941,
#   'Corporate',
#   'OFF-PA-10000350',
#   20,
#   20,
#   2,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [942,
#   'Corporate',
#   'OFF-BI-10001759',
#   10,
#   10,
#   2,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [943, 'Corporate', 'FUR-TA-10000577', 900, 1110, 4, 5, 55.5, 1054.5, 154.5],
#  [944,
#   'Consumer',
#   'OFF-PA-10004101',
#   30,
#   30,
#   5,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [945, 'Consumer', 'OFF-ST-10001496', 500, 540, 3, 5, 27.0, 513.0, 13.0],
#  [946,
#   'Consumer',
#   'OFF-BI-10002931',
#   150,
#   170,
#   5,
#   4,
#   6.8,
#   163.2,
#   13.199999999999989],
#  [947,
#   'Consumer',
#   'FUR-TA-10002356',
#   320,
#   390,
#   3,
#   3,
#   11.700000000000001,
#   378.3,
#   58.30000000000001],
#  [948, 'Home Office', 'FUR-FU-10003601', 420, 520, 7, 5, 26.0, 494.0, 74.0],
#  [949,
#   'Home Office',
#   'FUR-FU-10000576',
#   810,
#   1010,
#   6,
#   2,
#   20.2,
#   989.8,
#   179.79999999999995],
#  [950,
#   'Home Office',
#   'FUR-TA-10004154',
#   1950,
#   2070,
#   12,
#   5,
#   103.5,
#   1966.5,
#   16.5],
#  [951,
#   'Home Office',
#   'OFF-PA-10000788',
#   20,
#   20,
#   3,
#   3,
#   0.6,
#   19.4,
#   -0.6000000000000014],
#  [952,
#   'Home Office',
#   'OFF-PA-10002479',
#   20,
#   30,
#   6,
#   2,
#   0.6,
#   29.4,
#   9.399999999999999],
#  [953,
#   'Consumer',
#   'FUR-FU-10001940',
#   30,
#   30,
#   4,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  [954,
#   'Consumer',
#   'OFF-AR-10001958',
#   30,
#   30,
#   2,
#   2,
#   0.6,
#   29.4,
#   -0.6000000000000014],
#  [955, 'Consumer', 'FUR-BO-10004709', 70, 80, 2, 5, 4.0, 76.0, 6.0],
#  [956,
#   'Consumer',
#   'OFF-ST-10000604',
#   160,
#   170,
#   5,
#   4,
#   6.8,
#   163.2,
#   3.1999999999999886],
#  [957,
#   'Consumer',
#   'TEC-PH-10002923',
#   30,
#   30,
#   1,
#   4,
#   1.2,
#   28.8,
#   -1.1999999999999993],
#  [958, 'Consumer', 'OFF-BI-10004465', 0, 0, 2, 5, 0.0, 0.0, 0.0],
#  [959,
#   'Consumer',
#   'OFF-PA-10002333',
#   20,
#   20,
#   3,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [960, 'Consumer', 'FUR-FU-10004188', 190, 200, 2, 4, 8.0, 192.0, 2.0],
#  [961,
#   'Corporate',
#   'FUR-CH-10002965',
#   260,
#   320,
#   2,
#   2,
#   6.4,
#   313.6,
#   53.60000000000002],
#  [962,
#   'Home Office',
#   'OFF-BI-10000145',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [963, 'Corporate', 'OFF-EN-10001335', 20, 20, 2, 5, 1.0, 19.0, -1.0],
#  [964, 'Consumer', 'OFF-LA-10001613', 0, 0, 2, 5, 0.0, 0.0, 0.0],
#  [965,
#   'Home Office',
#   'OFF-LA-10004055',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [966, 'Home Office', 'OFF-AR-10004344', 40, 40, 3, 5, 2.0, 38.0, -2.0],
#  [967,
#   'Home Office',
#   'OFF-PA-10004621',
#   10,
#   10,
#   2,
#   3,
#   0.3,
#   9.7,
#   -0.3000000000000007],
#  [968,
#   'Home Office',
#   'OFF-PA-10001281',
#   180,
#   190,
#   4,
#   4,
#   7.6000000000000005,
#   182.4,
#   2.4000000000000057],
#  [969, 'Home Office', 'OFF-LA-10001613', 10, 10, 3, 5, 0.5, 9.5, -0.5],
#  [970, 'Home Office', 'OFF-ST-10001097', 420, 500, 3, 5, 25.0, 475.0, 55.0],
#  [971,
#   'Consumer',
#   'FUR-FU-10001095',
#   110,
#   130,
#   6,
#   4,
#   5.2,
#   124.8,
#   14.799999999999997],
#  [972,
#   'Consumer',
#   'TEC-PH-10004614',
#   110,
#   120,
#   3,
#   4,
#   4.8,
#   115.2,
#   5.200000000000003],
#  [973,
#   'Consumer',
#   'OFF-BI-10001575',
#   20,
#   20,
#   2,
#   4,
#   0.8,
#   19.2,
#   -0.8000000000000007],
#  [974, 'Consumer', 'OFF-LA-10001074', 20, 30, 3, 5, 1.5, 28.5, 8.5],
#  [975,
#   'Home Office',
#   'TEC-PH-10003555',
#   150,
#   160,
#   7,
#   4,
#   6.4,
#   153.6,
#   3.5999999999999943],
#  [976, 'Home Office', 'OFF-BI-10004492', 70, 80, 3, 5, 4.0, 76.0, 6.0],
#  [977, 'Consumer', 'OFF-BI-10002012', 0, 0, 2, 4, 0.0, 0.0, 0.0],
#  [978,
#   'Corporate',
#   'TEC-MA-10000822',
#   2850,
#   3060,
#   2,
#   3,
#   91.8,
#   2968.2,
#   118.19999999999982],
#  [979, 'Consumer', 'OFF-BI-10000848', 0, 0, 2, 2, 0.0, 0.0, 0.0],
#  [980,
#   'Corporate',
#   'OFF-PA-10004156',
#   30,
#   30,
#   3,
#   2,
#   0.6,
#   29.4,
#   -0.6000000000000014],
#  [981, 'Consumer', 'FUR-CH-10003199', 570, 600, 6, 5, 30.0, 570.0, 0.0],
#  [982, 'Consumer', 'OFF-AR-10000034', 0, 0, 1, 3, 0.0, 0.0, 0.0],
#  [983, 'Consumer', 'TEC-PH-10000560', 460, 560, 2, 5, 28.0, 532.0, 72.0],
#  [984, 'Consumer', 'FUR-CH-10000665', 550, 600, 5, 2, 12.0, 588.0, 38.0],
#  [985,
#   'Home Office',
#   'OFF-LA-10001569',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [986, 'Home Office', 'OFF-EN-10000461', 20, 30, 4, 5, 1.5, 28.5, 8.5],
#  [987,
#   'Home Office',
#   'TEC-MA-10003066',
#   320,
#   340,
#   3,
#   4,
#   13.6,
#   326.4,
#   6.399999999999977],
#  [988, 'Consumer', 'OFF-BI-10004022', 0, 0, 2, 3, 0.0, 0.0, 0.0],
#  [989,
#   'Corporate',
#   'FUR-FU-10004071',
#   490,
#   520,
#   5,
#   4,
#   20.8,
#   499.2,
#   9.199999999999989],
#  [990, 'Corporate', 'OFF-AR-10001988', 20, 20, 3, 5, 1.0, 19.0, -1.0],
#  [991, 'Home Office', 'FUR-CH-10004086', 1060, 1170, 5, 5, 58.5, 1111.5, 51.5],
#  [992,
#   'Consumer',
#   'OFF-BI-10001036',
#   10,
#   10,
#   2,
#   2,
#   0.2,
#   9.8,
#   -0.1999999999999993],
#  [993, 'Consumer', 'OFF-FA-10002983', 10, 10, 3, 5, 0.5, 9.5, -0.5],
#  [994, 'Consumer', 'OFF-PA-10003625', 120, 150, 5, 2, 3.0, 147.0, 27.0],
#  [995,
#   'Corporate',
#   'OFF-BI-10003925',
#   2200,
#   2720,
#   7,
#   2,
#   54.4,
#   2665.6,
#   465.5999999999999],
#  [996,
#   'Corporate',
#   'TEC-PH-10001530',
#   520,
#   620,
#   3,
#   2,
#   12.4,
#   607.6,
#   87.60000000000002],
#  [997,
#   'Consumer',
#   'OFF-EN-10003862',
#   10,
#   10,
#   1,
#   4,
#   0.4,
#   9.6,
#   -0.40000000000000036],
#  [998,
#   'Consumer',
#   'OFF-ST-10004258',
#   30,
#   40,
#   3,
#   3,
#   1.2,
#   38.8,
#   8.799999999999997],
#  [999,
#   'Consumer',
#   'FUR-FU-10002885',
#   20,
#   20,
#   5,
#   2,
#   0.4,
#   19.6,
#   -0.3999999999999986],
#  [1000,
#   'Consumer',
#   'FUR-FU-10001918',
#   30,
#   30,
#   7,
#   3,
#   0.9,
#   29.1,
#   -0.8999999999999986],
#  ...]

# %%
for i in data_file:
    data.execute(query,i)
mydb.commit()

# %%
import streamlit as st
import pymysql
import pandas as pd

# %%
mydb = pymysql.connect(
            host='127.0.0.1',
            user="root",
            password='sukil',
            database="retail_orders",
            autocommit=True
        )
mycursor = mydb.cursor()
#st.success("Connected to the database successfully!")

st.title("RETAIL_ORDERS")
st.header("GIVEN QUERIES:")

mycursor.execute('use retail_orders')

if st.button("1"):
     st.markdown(" Find top 10 highest revenue generating products:")
     mycursor.execute('''SELECT table_05.product_id, SUM(table_05.sale_price * table_05.quantity) AS revenue
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_05.product_id
ORDER BY revenue DESC
LIMIT 10;
''')
     st.table(mycursor)


if st.button("2"):
     st.markdown("Find the top 5 cities with the highest profit margins:")
     mycursor.execute('''SELECT table_0.city, SUM(table_05.profit) AS total_profit
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.city
ORDER BY total_profit DESC
LIMIT 5;
''')
     st.table(mycursor)

if st.button("3"):
     st.markdown("Calculate the total discount given for each category:")
     mycursor.execute('''SELECT table_0.category, SUM(table_05.discount) AS total_discount
FROM table_0
JOIN table_05 ON table_0.order_id =table_05.order_id
GROUP BY table_0.category;
''' )
     st.table(mycursor)

if st.button("4"):
     st.markdown("Find the average sale price per product category:")
     mycursor.execute('''SELECTtable_0.category, AVG(table_05.sale_price) AS avg_sale_price
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category;
''' )
     st.table(mycursor)

if st.button("5"):
     st.markdown("Find the region with the highest average sale price:")
     mycursor.execute('''SELECT table_0.region, AVG(table_05.sale_price) AS avg_sale_price
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.region
ORDER BY avg_sale_price DESC
LIMIT 1;
''')
     st.table(mycursor)

if st.button("6"):
     st.markdown("Find the total profit per category:")
     mycursor.execute('''SELECT table_0.category, SUM(table_05.profit) AS total_profit
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category;
''' )
     st.table(mycursor)

if st.button("7"):
     st.markdown(" Identify the top 3 segments with the highest quantity of orders:")
     mycursor.execute('''SELECT table_05.segment, SUM(table_05.quantity) AS total_quantity
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_05.segment
ORDER BY total_quantity DESC
LIMIT 3;
 ''')
     st.table(mycursor)

if st.button("8"):
     st.markdown("Determine the average discount percentage given per region:")
     mycursor.execute('''SELECTtable_0.region, AVG(table_05.discount_percent) AS avg_discount_percent
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.region;
'''  )
     st.table(mycursor)

if st.button("9"):
     st.markdown("Find the product category with the highest total profit:")
     mycursor.execute('''SELECT table_0.category, SUM(table_05.profit) AS total_profit
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category
ORDER BY total_profit DESC
LIMIT 1;
 ''' )
     st.table(mycursor)

if st.button("10"):
     st.markdown("Calculate the total revenue generated per year:")
     mycursor.execute('''SELECT YEAR(table_0.order_date) AS year, 
       SUM(table_05.sale_price * table_05.quantity) AS total_revenue
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY YEAR(table_0.order_date)
''')
     st.table(mycursor)

st.header("MY OWN GIVEN QUERIES:")

if st.button("11"):
     st.markdown("Find the top 5 lowest revenue generating products:")
     mycursor.execute('''SELECT table_05.product_id, SUM(table_05.sale_price * table_05.quantity) AS revenue
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_05.product_id
ORDER BY revenue ASC
LIMIT 5;
 ''' )
     st.table(mycursor)

if st.button("12"):
     st.markdown("Find the top 5 cities with the lowest profit margins:")
     mycursor.execute('''
        SELECT table_0.city, SUM(table_05.profit) AS total_profit
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.city
ORDER BY total_profit ASC
LIMIT 5;
   '''  )
     st.table(mycursor)

if st.button("13"):
     st.markdown("Calculate the total discount given for each category:")
     mycursor.execute('''
        SELECT table_0.category, SUM(table_05.discount) AS total_discount
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category;
  '''   )
     st.table(mycursor)

if st.button("14"):
     st.markdown("Find the average sale price per product category:")
     mycursor.execute('''
        SELECT table_0.category, AVG(table_05.sale_price) AS avg_sale_price
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category;
''')
     st.table(mycursor)

if st.button("15"):
     st.markdown("Find the region with the lowest average sale price:")
     mycursor.execute('''
        SELECT table_0.region, AVG(table_05.sale_price) AS avg_sale_price
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.region
ORDER BY avg_sale_price ASC
LIMIT 1;
''')
     st.table(mycursor)

if st.button("16"):
     st.markdown(" Find the total profit for each category:")
     mycursor.execute('''
        SELECT table_0.category, SUM(table_05.profit) AS total_profit
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category;
'''  )
     st.table(mycursor)

if st.button("17"):
     st.markdown("Identify the top 5 segments with the lowest quantity of orders:")
     mycursor.execute('''
        SELECT table_05.segment, SUM(table_05.quantity) AS total_quantity
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_05.segment
ORDER BY total_quantity ASC
LIMIT 5;
''' )
     st.table(mycursor)

if st.button("18"):
     st.markdown("Determine the average discount percentage given for total revenue:")
     mycursor.execute('''
        SELECT SUM(table_05.sale_price * table_05.quantity) AS total_revenue,
       AVG(table_05.discount_percent) AS avg_discount_percent
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id;
''' )
     st.table(mycursor)

if st.button("19"):
     st.markdown("Find the product category with the lowest total profit:")
     mycursor.execute('''
        SELECT table_0.category, SUM(table_05.profit) AS total_profit
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.category
ORDER BY total_profit ASC
LIMIT 1;
''' )
     st.table(mycursor)

if st.button("20"):
     st.markdown(" Calculate the total revenue generated per day:")
     mycursor.execute('''SELECT table_0.order_date, SUM(table_05.sale_price * table_05.quantity) AS total_revenue
FROM table_0
JOIN table_05 ON table_0.order_id = table_05.order_id
GROUP BY table_0.order_date
ORDER BY table_0.order_date;
''' )
     st.table(mycursor)
